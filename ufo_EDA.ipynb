# %% [markdown]
# ## UFO Sighting Data Cleaning

# %%
import pandas as pd

ufo_data = pd.read_csv("C:/Users/mayap/Downloads/DV_Lab01/nuforc_reports.csv/nuforc_reports.csv")
ufo_data
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# 0        VA  2019-12-12T18:43:00      light    5 seconds
# 1        CT  2019-03-22T18:30:00     circle  3-5 seconds
# 2       NaN                  NaN        NaN          NaN
# 3        ON  2019-04-17T02:00:00   teardrop   10 seconds
# 4        NY  2009-03-15T18:00:00      cigar    2 minutes
# ...     ...                  ...        ...          ...
# 88120    AZ  2019-10-02T20:00:00  formation    3 minutes
# 88121    MO  2019-10-02T20:00:00      light   20 seconds
# 88122    FL  2019-10-02T20:03:00  formation   20 seconds
# 88123    NC  2019-10-02T22:00:00   fireball    2 minutes
# 88124    CA  2019-10-02T22:00:00     sphere    3 minutes
#
#                                                    stats  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2      Occurred : 4/1/2019 15:45  (Entered as : April...
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 4      Occurred : 3/15/2009 18:00  (Entered as : 03/1...
# ...                                                  ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 2      http://www.nuforc.org/webreports/145/S145556.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 2      I woke up late in the afternoon 3:30-4pm.  I w...                  NaN
# 3      I was driving towards the intersection of fall...  2019-04-18T00:00:00
# 4      In Peoria, Arizona, I saw a cigar shaped craft...  2019-04-18T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 2                NaN             NaN
# 3          45.381383      -75.708501
# 4                NaN             NaN
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [88125 rows x 12 columns]

# %% [markdown]
# #### Removing unnesseccary or redundent columns

# %%
ufo_data = ufo_data.drop(['report_link', 'summary', 'stats'], axis=1)

ufo_data
# Out:
#                  city state            date_time      shape     duration  \
# 0             Chester    VA  2019-12-12T18:43:00      light    5 seconds
# 1          Rocky Hill    CT  2019-03-22T18:30:00     circle  3-5 seconds
# 2                 NaN   NaN                  NaN        NaN          NaN
# 3              Ottawa    ON  2019-04-17T02:00:00   teardrop   10 seconds
# 4              Peoria    NY  2009-03-15T18:00:00      cigar    2 minutes
# ...               ...   ...                  ...        ...          ...
# 88120           Tempe    AZ  2019-10-02T20:00:00  formation    3 minutes
# 88121         Bolivar    MO  2019-10-02T20:00:00      light   20 seconds
# 88122      North Port    FL  2019-10-02T20:03:00  formation   20 seconds
# 88123  Black Mountain    NC  2019-10-02T22:00:00   fireball    2 minutes
# 88124    Marin County    CA  2019-10-02T22:00:00     sphere    3 minutes
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 2      I woke up late in the afternoon 3:30-4pm.  I w...                  NaN
# 3      I was driving towards the intersection of fall...  2019-04-18T00:00:00
# 4      In Peoria, Arizona, I saw a cigar shaped craft...  2019-04-18T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 2                NaN             NaN
# 3          45.381383      -75.708501
# 4                NaN             NaN
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [88125 rows x 9 columns]

# %% [markdown]
# #### Shapes

# %%
shapes_dict = dict()
for shape in ufo_data['shape']:
    if shape not in shapes_dict:
        shapes_dict[shape] = 1
    else:
        shapes_dict[shape] += 1

shapes_dict
# Out:
# {'light': 18230,
#  'circle': 10130,
#  nan: 2498,
#  'teardrop': 767,
#  'cigar': 1990,
#  'disk': 4522,
#  'unknown': 6182,
#  'oval': 3857,
#  'other': 5749,
#  'sphere': 6065,
#  'changing': 2112,
#  'formation': 2842,
#  'flash': 1675,
#  'chevron': 953,
#  'triangle': 7910,
#  'cylinder': 1374,
#  'fireball': 7095,
#  'diamond': 1273,
#  'egg': 666,
#  'cross': 289,
#  'rectangle': 1597,
#  'cone': 349}

# %% [markdown]
# #### States
# Thinking of removing entries from outside the US

# %%
state_dict = dict()
for state in ufo_data['state']:
    if state not in state_dict:
        state_dict[state] = 1
    else:
        state_dict[state] += 1

state_dict
# Out:
# {'VA': 1768,
#  'CT': 1335,
#  nan: 5235,
#  'ON': 1410,
#  'NY': 3425,
#  'TX': 3481,
#  'AZ': 2893,
#  'IN': 1598,
#  'FL': 5294,
#  'NM': 1026,
#  'IA': 749,
#  'SC': 1601,
#  'CA': 9506,
#  'CO': 1888,
#  'RI': 406,
#  'TN': 1432,
#  'PA': 3115,
#  'NJ': 1797,
#  'WA': 3856,
#  'MI': 2258,
#  'MO': 1697,
#  'IL': 2539,
#  'OH': 2723,
#  'OR': 2001,
#  'MA': 1707,
#  'WY': 228,
#  'KY': 1044,
#  'NC': 2442,
#  'AR': 669,
#  'OK': 881,
#  'QC': 195,
#  'AB': 381,
#  'AL': 869,
#  'SD': 253,
#  'MD': 1189,
#  'ME': 732,
#  'GA': 1770,
#  'MN': 1332,
#  'NV': 972,
#  'LA': 717,
#  'WI': 1498,
#  'UT': 929,
#  'MS': 479,
#  'BC': 473,
#  'MT': 647,
#  'NH': 760,
#  'ID': 832,
#  'NB': 146,
#  'WV': 567,
#  'DC': 87,
#  'NE': 422,
#  'KS': 706,
#  'MB': 147,
#  'AK': 419,
#  'NS': 136,
#  'SK': 127,
#  'NT': 10,
#  'VT': 413,
#  'ND': 158,
#  'HI': 434,
#  'DE': 262,
#  'NL': 26,
#  'PR': 2,
#  'YT': 17,
#  'PE': 13,
#  'QB': 1}

# %%
# Create a set of valid state codes
valid_states = {
    'VA', 'CT', 'NY', 'TX', 'AZ', 'IN', 'FL', 'NM', 'IA', 'SC', 'CA', 'CO', 
    'RI', 'TN', 'PA', 'NJ', 'WA', 'MI', 'MO', 'IL', 'OH', 'OR', 'MA', 'WY', 
    'KY', 'NC', 'AR', 'OK', 'AL', 'SD', 'MD', 'ME', 'GA', 'MN', 'NV', 'LA', 
    'WI', 'UT', 'MS', 'MT', 'NH', 'ID', 'WV', 'DC', 'NE', 'KS', 'AK', 'VT', 
    'ND', 'HI', 'DE'
}

# Filter ufo_data to include only rows where the 'state' is in valid_states
USA_ufo_data = ufo_data[ufo_data['state'].isin(valid_states)]

# View the filtered DataFrame
USA_ufo_data
# Out:
#                  city state            date_time      shape     duration  \
# 0             Chester    VA  2019-12-12T18:43:00      light    5 seconds
# 1          Rocky Hill    CT  2019-03-22T18:30:00     circle  3-5 seconds
# 4              Peoria    NY  2009-03-15T18:00:00      cigar    2 minutes
# 5          Kirbyville    TX  2019-04-02T20:25:00       disk   15 minutes
# 6              Tucson    AZ  2019-05-01T11:00:00    unknown    5 minutes
# ...               ...   ...                  ...        ...          ...
# 88120           Tempe    AZ  2019-10-02T20:00:00  formation    3 minutes
# 88121         Bolivar    MO  2019-10-02T20:00:00      light   20 seconds
# 88122      North Port    FL  2019-10-02T20:03:00  formation   20 seconds
# 88123  Black Mountain    NC  2019-10-02T22:00:00   fireball    2 minutes
# 88124    Marin County    CA  2019-10-02T22:00:00     sphere    3 minutes
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 4      In Peoria, Arizona, I saw a cigar shaped craft...  2019-04-18T00:00:00
# 5      The object has flashing lights that are green,...  2019-04-08T00:00:00
# 6      Description is the same as Washington, DC, eve...  2019-05-09T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 4                NaN             NaN
# 5          30.677200      -94.005200
# 6          32.259941     -110.927542
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [79806 rows x 9 columns]

# %% [markdown]
# #### Date and Time
#
# Converted the columns referring to time to a usable format, then added the difference between when the sighting occurred and when it was posted in minutes

# %%
ufo_data['date_time'] = pd.to_datetime(ufo_data['date_time'])
ufo_data['posted'] = pd.to_datetime(ufo_data['posted'])

ufo_data['time_diff_minutes'] = (ufo_data['posted'] - ufo_data['date_time']).dt.total_seconds() / 60


ufo_data
# Out:
#                  city state           date_time      shape     duration  \
# 0             Chester    VA 2019-12-12 18:43:00      light    5 seconds
# 1          Rocky Hill    CT 2019-03-22 18:30:00     circle  3-5 seconds
# 2                 NaN   NaN                 NaT        NaN          NaN
# 3              Ottawa    ON 2019-04-17 02:00:00   teardrop   10 seconds
# 4              Peoria    NY 2009-03-15 18:00:00      cigar    2 minutes
# ...               ...   ...                 ...        ...          ...
# 88120           Tempe    AZ 2019-10-02 20:00:00  formation    3 minutes
# 88121         Bolivar    MO 2019-10-02 20:00:00      light   20 seconds
# 88122      North Port    FL 2019-10-02 20:03:00  formation   20 seconds
# 88123  Black Mountain    NC 2019-10-02 22:00:00   fireball    2 minutes
# 88124    Marin County    CA 2019-10-02 22:00:00     sphere    3 minutes
#
#                                                     text     posted  \
# 0      My wife was driving southeast on a fairly popu... 2019-12-22
# 1      I think that I may caught a UFO on the NBC Nig... 2019-03-29
# 2      I woke up late in the afternoon 3:30-4pm.  I w...        NaT
# 3      I was driving towards the intersection of fall... 2019-04-18
# 4      In Peoria, Arizona, I saw a cigar shaped craft... 2019-04-18
# ...                                                  ...        ...
# 88120  4 lights in formation over Tempe appear while ... 2019-10-04
# 88121  2 bright star like lights in the NNW sky two b... 2019-10-04
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428... 2019-10-04
# 88123  Witnessed an orange, slow moving light. Was lo... 2019-10-04
# 88124  Glowing lights in formation  just south of San... 2019-10-04
#
#        city_latitude  city_longitude  time_diff_minutes
# 0          37.343152      -77.408582            13277.0
# 1          41.664800      -72.639300             8970.0
# 2                NaN             NaN                NaN
# 3          45.381383      -75.708501             1320.0
# 4                NaN             NaN          5306760.0
# ...              ...             ...                ...
# 88120      33.414036     -111.920920             1680.0
# 88121      37.642200      -93.399600             1680.0
# 88122      27.076210      -82.223280             1677.0
# 88123      35.605000      -82.313200             1560.0
# 88124            NaN             NaN             1560.0
#
# [88125 rows x 10 columns]

# %% [markdown]
# 780 reports where reported BEFORE a UFO was sighted :/
# Maybe we could look into similarities in the set and compare to more valid appearing sightings

# %%
ufo_data[ufo_data['time_diff_minutes'] < 0]
# Out:
#                      city state           date_time      shape       duration  \
# 270         Turners Falls    MA 2019-03-21 04:30:00      light        2.5 hrs
# 1496   Darwin (Australia)   NaN 2006-05-15 01:21:00    unknown      2 seconds
# 2083            Paulsboro    NJ 2019-08-23 00:17:00    unknown       1 minute
# 2084            Paulsboro    NJ 2019-08-23 00:17:00    unknown       1 minute
# 2138             Savannah    GA 2019-08-23 00:45:00    chevron     10 minutes
# ...                   ...   ...                 ...        ...            ...
# 85697          Ridgeville    SC 2018-11-24 03:45:00  rectangle    5-7 minutes
# 85698            Lawrence    KS 2019-10-04 11:35:00    chevron      5 MINUTES
# 85714          Wilmington    NC 2019-12-29 20:40:00      cigar     10 seconds
# 87924            Woolwich    ME 2019-12-01 00:30:00      other     20 minutes
# 87925   Næstved (Denmark)   NaN 2019-12-01 06:35:00      light  5-10 minutess
#
#                                                     text     posted  \
# 270    Mysterious light very bright to nothing and ba... 2019-03-21
# 1496   UFO uses asteroid signiture for orbit entry It... 2006-05-15
# 2083   Aircraft moving left to right over Delaware Ri... 2019-08-23
# 2084   UFO with white light and green (ultra light) m... 2019-08-23
# 2138   Flashing blue lights one solid red in the midd... 2019-08-23
# ...                                                  ...        ...
# 85697  Leaving Volvo plant from night shift, turned i... 2018-11-24
# 85698  AT ABOUT 11:35 AM THIS MORNING, WE HEARD A SMA... 2019-10-04
# 85714  7-8 elongated objects flying in straight line ... 2019-12-01
# 87924  As I was driving home from working in Bath wit... 2019-12-01
# 87925  Many lights fly in line across the sky I was o... 2019-12-01
#
#        city_latitude  city_longitude  time_diff_minutes
# 270        42.633924      -72.506165             -270.0
# 1496             NaN             NaN              -81.0
# 2083       39.835300      -75.195400              -17.0
# 2084       39.835300      -75.195400              -17.0
# 2138       32.029701      -81.135253              -45.0
# ...              ...             ...                ...
# 85697      33.057300      -80.319000             -225.0
# 85698      39.000100      -95.254588             -695.0
# 85714      34.238375      -77.878468           -41560.0
# 87924      43.956500      -69.765300              -30.0
# 87925            NaN             NaN             -395.0
#
# [788 rows x 10 columns]

# %% [markdown]
# Most seem to be reported right away

# %%
import matplotlib.pyplot as plt

# Drop any NaN values in the column (just in case)
time_diffs = ufo_data['time_diff_minutes'].dropna()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(time_diffs, bins=100, color='skyblue', edgecolor='black')
plt.title('Distribution of Time Differences (in minutes)')
plt.xlabel('Time Difference (minutes)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Text Analysis
#
# Created a word count column

# %%
word_counts = []

for text in ufo_data['text']:
    if isinstance(text, str):
        word_counts.append(len(text.split()))
    else:
        word_counts.append(0)

ufo_data['word_count'] = word_counts
ufo_data
# Out:
#                  city state           date_time      shape     duration  \
# 0             Chester    VA 2019-12-12 18:43:00      light    5 seconds
# 1          Rocky Hill    CT 2019-03-22 18:30:00     circle  3-5 seconds
# 2                 NaN   NaN                 NaT        NaN          NaN
# 3              Ottawa    ON 2019-04-17 02:00:00   teardrop   10 seconds
# 4              Peoria    NY 2009-03-15 18:00:00      cigar    2 minutes
# ...               ...   ...                 ...        ...          ...
# 88120           Tempe    AZ 2019-10-02 20:00:00  formation    3 minutes
# 88121         Bolivar    MO 2019-10-02 20:00:00      light   20 seconds
# 88122      North Port    FL 2019-10-02 20:03:00  formation   20 seconds
# 88123  Black Mountain    NC 2019-10-02 22:00:00   fireball    2 minutes
# 88124    Marin County    CA 2019-10-02 22:00:00     sphere    3 minutes
#
#                                                     text     posted  \
# 0      My wife was driving southeast on a fairly popu... 2019-12-22
# 1      I think that I may caught a UFO on the NBC Nig... 2019-03-29
# 2      I woke up late in the afternoon 3:30-4pm.  I w...        NaT
# 3      I was driving towards the intersection of fall... 2019-04-18
# 4      In Peoria, Arizona, I saw a cigar shaped craft... 2019-04-18
# ...                                                  ...        ...
# 88120  4 lights in formation over Tempe appear while ... 2019-10-04
# 88121  2 bright star like lights in the NNW sky two b... 2019-10-04
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428... 2019-10-04
# 88123  Witnessed an orange, slow moving light. Was lo... 2019-10-04
# 88124  Glowing lights in formation  just south of San... 2019-10-04
#
#        city_latitude  city_longitude  time_diff_minutes  word_count
# 0          37.343152      -77.408582            13277.0         185
# 1          41.664800      -72.639300             8970.0          73
# 2                NaN             NaN                NaN         178
# 3          45.381383      -75.708501             1320.0          49
# 4                NaN             NaN          5306760.0         211
# ...              ...             ...                ...         ...
# 88120      33.414036     -111.920920             1680.0         118
# 88121      37.642200      -93.399600             1680.0          78
# 88122      27.076210      -82.223280             1677.0         113
# 88123      35.605000      -82.313200             1560.0          72
# 88124            NaN             NaN             1560.0         107
#
# [88125 rows x 11 columns]

# %% [markdown]
# most seem to be short reportings

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(ufo_data['word_count'], bins=50, color='lightgreen', edgecolor='black')
plt.title('Histogram of Word Counts in UFO Reports')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Location and Coords
#
# No rows where the city is not stated, but the coords are, but over 15,000 records where the city is known, but the coords aren't. I want to look up approx coords based on the city and state

# %%
ufo_data[ufo_data['city'].isna() & (~ufo_data['city_longitude'].isna())]
# Out:
# Empty DataFrame
# Columns: [city, state, date_time, shape, duration, text, posted, city_latitude, city_longitude, time_diff_minutes, word_count]
# Index: []

# %%
ufo_data[(ufo_data['city_longitude'].isna() | ufo_data['city_latitude'].isna()) & (~ufo_data['city'].isna())]
# Out:
#                               city state           date_time    shape  \
# 4                           Peoria    NY 2009-03-15 18:00:00    cigar
# 9      Caloocan City (Philippines)   NaN 2019-06-06 19:00:00    other
# 18                          Leyner    CO 2019-08-09 20:22:00    light
# 19                        Catalina    AZ 2019-08-09 20:30:00    cigar
# 23                    Marin County    CA 2019-08-01 22:30:00   sphere
# ...                            ...   ...                 ...      ...
# 88112                      Hayfork    CA 2019-10-02 01:00:00  unknown
# 88113                     Limerick    PA 2019-10-02 03:26:00   circle
# 88114                     Limerick    PA 2019-10-02 03:26:00   circle
# 88117                      Hayfork    CA 2019-10-02 12:00:00      NaN
# 88124                 Marin County    CA 2019-10-02 22:00:00   sphere
#
#              duration                                               text  \
# 4           2 minutes  In Peoria, Arizona, I saw a cigar shaped craft...
# 9      19:00 to 19:30  group of lights formation sweeping thru a nigh...
# 18         20 minutes  There where 4 bright lights in a shape of a di...
# 19         40 seconds  My wife and I were taking our usual evening st...
# 23          3 minutes  7 stationary brightly lit objects seen  over h...
# ...               ...                                                ...
# 88112       3 minutes  Don't care it happend A craft came over us the...
# 88113      20 seconds  ((NUFORC Note:  Witness does not include any d...
# 88114      20 seconds  I was driving to work and I’m the only one on ...
# 88117       7 minutes  On history channel there should be a contact #...
# 88124       3 minutes  Glowing lights in formation  just south of San...
#
#           posted  city_latitude  city_longitude  time_diff_minutes  word_count
# 4     2019-04-18            NaN             NaN          5306760.0         211
# 9     2019-06-07            NaN             NaN              300.0         114
# 18    2019-08-23            NaN             NaN            18938.0          36
# 19    2019-08-23            NaN             NaN            18930.0          77
# 23    2019-08-23            NaN             NaN            30330.0         126
# ...          ...            ...             ...                ...         ...
# 88112 2019-10-04            NaN             NaN             2820.0          26
# 88113 2019-10-04            NaN             NaN             2674.0          13
# 88114 2019-10-04            NaN             NaN             2674.0         177
# 88117 2019-10-04            NaN             NaN             2160.0          14
# 88124 2019-10-04            NaN             NaN             1560.0         107
#
# [15875 rows x 11 columns]

# %%
import geopy
from geopy.geocoders import Nominatim
import time

def get_coordinates(city, state, cache):
    # Check if the coordinates are already cached
    if (city, state) in cache:
        return cache[(city, state)]
    
    geolocator = Nominatim(user_agent="ufo_sighting_locations")
    location = geolocator.geocode(f"{city}, {state}", timeout=10)
    
    if location:
        # Cache the coordinates to avoid redundant requests
        cache[(city, state)] = (location.latitude, location.longitude)
        return location.latitude, location.longitude
    else:
        return None, None

cache = {}

# Example usage
city = "Lauglintown"
state = "PA"
latitude, longitude = get_coordinates(city, state, cache)
print(f"Latitude: {latitude}, Longitude: {longitude}")
# Out:
# Latitude: None, Longitude: None

# %%
USA_ufo_data = ufo_data[ufo_data['state'].isin(valid_states)]
USA_ufo_data
# Out:
#                  city state           date_time      shape     duration  \
# 0             Chester    VA 2019-12-12 18:43:00      light    5 seconds
# 1          Rocky Hill    CT 2019-03-22 18:30:00     circle  3-5 seconds
# 4              Peoria    NY 2009-03-15 18:00:00      cigar    2 minutes
# 5          Kirbyville    TX 2019-04-02 20:25:00       disk   15 minutes
# 6              Tucson    AZ 2019-05-01 11:00:00    unknown    5 minutes
# ...               ...   ...                 ...        ...          ...
# 88120           Tempe    AZ 2019-10-02 20:00:00  formation    3 minutes
# 88121         Bolivar    MO 2019-10-02 20:00:00      light   20 seconds
# 88122      North Port    FL 2019-10-02 20:03:00  formation   20 seconds
# 88123  Black Mountain    NC 2019-10-02 22:00:00   fireball    2 minutes
# 88124    Marin County    CA 2019-10-02 22:00:00     sphere    3 minutes
#
#                                                     text     posted  \
# 0      My wife was driving southeast on a fairly popu... 2019-12-22
# 1      I think that I may caught a UFO on the NBC Nig... 2019-03-29
# 4      In Peoria, Arizona, I saw a cigar shaped craft... 2019-04-18
# 5      The object has flashing lights that are green,... 2019-04-08
# 6      Description is the same as Washington, DC, eve... 2019-05-09
# ...                                                  ...        ...
# 88120  4 lights in formation over Tempe appear while ... 2019-10-04
# 88121  2 bright star like lights in the NNW sky two b... 2019-10-04
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428... 2019-10-04
# 88123  Witnessed an orange, slow moving light. Was lo... 2019-10-04
# 88124  Glowing lights in formation  just south of San... 2019-10-04
#
#        city_latitude  city_longitude  time_diff_minutes  word_count
# 0          37.343152      -77.408582            13277.0         185
# 1          41.664800      -72.639300             8970.0          73
# 4                NaN             NaN          5306760.0         211
# 5          30.677200      -94.005200             7415.0         284
# 6          32.259941     -110.927542            10860.0          26
# ...              ...             ...                ...         ...
# 88120      33.414036     -111.920920             1680.0         118
# 88121      37.642200      -93.399600             1680.0          78
# 88122      27.076210      -82.223280             1677.0         113
# 88123      35.605000      -82.313200             1560.0          72
# 88124            NaN             NaN             1560.0         107
#
# [79806 rows x 11 columns]

# %%
missing_coords = USA_ufo_data[
    pd.notna(USA_ufo_data['city']) & 
    pd.notna(USA_ufo_data['state']) & 
    pd.isna(USA_ufo_data['city_latitude']) & 
    pd.isna(USA_ufo_data['city_longitude'])
]

locations_missing_coords = set(
    zip(missing_coords['state'], 
        [x for x in missing_coords['city'] if len(x.split()) == 1])
)
print(len(locations_missing_coords))
locations_missing_coords
# Out:
# 5029
# {('ME', 'Yorktown'),
#  ('WA', 'Virginia'),
#  ('WV', 'Espanola'),
#  ('OH', 'Ewing'),
#  ('CA', 'Bethera'),
#  ('ID', 'Brady'),
#  ('IL', 'Brownstown'),
#  ('PA', 'Phila.'),
#  ('MA', 'Rome'),
#  ('LA', 'Topsail'),
#  ('MI', 'Austin'),
#  ('SC', 'Walker'),
#  ('OR', 'Cascabels'),
#  ('OR', 'Kearns'),
#  ('FL', 'Kyburz'),
#  ('MN', 'LaVeta'),
#  ('MA', 'Woodbury'),
#  ('MN', 'Wickieup'),
#  ('WA', 'Brookside'),
#  ('VT', 'Burgin'),
#  ('AZ', 'Fairfax'),
#  ('NY', 'Rogerson'),
#  ('OH', 'Coates'),
#  ('MI', 'Hamburg'),
#  ('WA', 'Clinton'),
#  ('VT', 'Uintah'),
#  ('WA', 'Cheek'),
#  ('NJ', 'Phillipsville'),
#  ('MS', 'Stanfield'),
#  ('OR', 'Brier'),
#  ('VA', 'Woodbury'),
#  ('CA', 'Mardela'),
#  ('MN', 'Oolagah'),
#  ('UT', 'none'),
#  ('TX', 'Marlboro'),
#  ('AZ', 'Everglades'),
#  ('MN', 'Trio'),
#  ('TX', 'Sunflower'),
#  ('TX', 'Manalapan'),
#  ('FL', 'Sodaville'),
#  ('IL', 'Colonie'),
#  ('AK', 'Lantana'),
#  ('MT', 'Brick'),
#  ('OH', 'Seatac'),
#  ('CA', 'Ammon'),
#  ('PA', 'Honokaa'),
#  ('CA', 'Colebrook'),
#  ('CA', 'Mahanoy'),
#  ('CA', 'Thetford'),
#  ('CA', 'Knifley'),
#  ('MA', 'Espanola'),
#  ('MO', 'Success'),
#  ('NY', 'Yosemite'),
#  ('CA', 'Irondequoit'),
#  ('OH', 'Light'),
#  ('MD', 'Maycomb'),
#  ('UT', 'Grover'),
#  ('GA', 'Nevada'),
#  ('NY', 'Tomahawk'),
#  ('OK', 'Bernard'),
#  ('MA', 'Plains'),
#  ('NY', 'Fridley'),
#  ('CA', 'Destrahan'),
#  ('CA', 'Moxee'),
#  ('WI', 'Saugus'),
#  ('NJ', 'Portchester'),
#  ('MO', 'Northboro'),
#  ('FL', 'Clinton'),
#  ('FL', 'Laura'),
#  ('SC', 'Cornwallville'),
#  ('MO', 'Vestavia'),
#  ('MO', 'Gladstone'),
#  ('WA', 'Lola'),
#  ('NV', 'Easton'),
#  ('VA', 'Plains'),
#  ('NJ', 'Williamsville'),
#  ('OK', 'Shicksinny'),
#  ('KY', 'Chichester'),
#  ('FL', 'Hackberry'),
#  ('WA', 'Rodanthe'),
#  ('PA', 'Robbinsville'),
#  ('FL', 'Uhland'),
#  ('MI', 'Calais'),
#  ('CA', 'Powdersville'),
#  ('NJ', 'Northglenn'),
#  ('IL', 'Whitemarsh'),
#  ('MI', 'Wellington'),
#  ('DE', 'Westchester'),
#  ('OH', 'Adamsville'),
#  ('KY', 'Frenchberg'),
#  ('NM', 'Blanford'),
#  ('AK', 'Reading'),
#  ('TX', 'Lagrange'),
#  ('VT', 'Merton'),
#  ('NJ', 'Holladay'),
#  ('KS', 'Edina'),
#  ('NC', 'Ardsley'),
#  ('MD', 'Orient'),
#  ('VT', 'Feltham'),
#  ('PA', 'Hurley'),
#  ('FL', 'Schaumurg'),
#  ('VT', 'Lyndon'),
#  ('AZ', 'Fruitland'),
#  ('VA', 'Nortvale'),
#  ('PA', 'Gillham'),
#  ('MO', 'Ewan'),
#  ('OR', 'Volcano'),
#  ('NC', 'Cary'),
#  ('NJ', 'Burien'),
#  ('NY', 'Kensington'),
#  ('IA', 'LaPorte'),
#  ('MO', 'Morton'),
#  ('TX', 'Raytown'),
#  ('NM', 'Joppatowne'),
#  ('NJ', 'Turner'),
#  ('NY', 'Belgreen'),
#  ('NY', 'Napavine'),
#  ('NV', 'Henderson'),
#  ('CA', 'Mizpah'),
#  ('NV', 'Westport'),
#  ('MN', 'Henrico'),
#  ('AL', 'Pittsburg'),
#  ('ME', 'Martinez'),
#  ('OR', 'Bullock'),
#  ('AL', 'Bainbridge'),
#  ('CA', 'LaGrange'),
#  ('IN', 'Mayfeld'),
#  ('OR', 'Morgantown'),
#  ('NJ', 'Surfside'),
#  ('MN', 'Knightsen'),
#  ('NJ', 'Nothing'),
#  ('PA', 'Concord'),
#  ('TX', 'Cherry'),
#  ('CA', 'Lakeland'),
#  ('IN', 'Gahanna'),
#  ('AZ', 'Roach'),
#  ('CA', 'York'),
#  ('NM', 'In-flight'),
#  ('HI', 'Bakersfield?'),
#  ('WA', 'Gray'),
#  ('AZ', 'Estes'),
#  ('NJ', 'Downer'),
#  ('IL', 'Blackjack'),
#  ('CA', 'Smithport'),
#  ('WA', 'Shoreview'),
#  ('KS', 'Garibaldi'),
#  ('CA', 'Everywhere'),
#  ('VT', 'Willowdale'),
#  ('OH', 'Lacassine'),
#  ('FL', 'Algona'),
#  ('HI', 'Winter'),
#  ('MO', 'Fortuna'),
#  ('OH', 'Largo'),
#  ('WA', 'Dorchester'),
#  ('NJ', 'Sacaton'),
#  ('WA', 'Niota'),
#  ('IL', 'Pleasanton'),
#  ('LA', 'Winifrede'),
#  ('IL', 'Athena'),
#  ('FL', 'Exeter'),
#  ('AR', 'Long'),
#  ('RI', 'Paradise'),
#  ('AK', 'Unknown'),
#  ('GA', 'Moxee'),
#  ('WA', 'Irma'),
#  ('FL', 'Stoninigton'),
#  ('FL', 'Niskayuna'),
#  ('AL', 'Blaine'),
#  ('IN', 'Peidmont'),
#  ('OR', 'Ahwatukee'),
#  ('MO', 'Jasonvill'),
#  ('NY', 'Gibert'),
#  ('NM', 'Wellington'),
#  ('CA', 'Koshkonong'),
#  ('CO', 'Pep'),
#  ('PA', 'Gladstone'),
#  ('AZ', 'Centennial'),
#  ('WA', 'Elkmomt'),
#  ('PA', 'NSL'),
#  ('TX', 'Newbury'),
#  ('HI', 'Oakhill'),
#  ('SC', 'Sedona'),
#  ('NJ', 'Zanesville'),
#  ('ME', 'Hope'),
#  ('TX', 'Cedarville'),
#  ('CA', 'Humnoke'),
#  ('ME', 'Filmore'),
#  ('MN', 'Catawba'),
#  ('MI', 'Morganza'),
#  ('NV', 'Finley'),
#  ('MD', 'Centralia'),
#  ('NJ', 'Gainsville'),
#  ('IL', 'Tanacross'),
#  ('FL', 'Sea-Tac'),
#  ('FL', 'Concord'),
#  ('MN', "Kapa'a"),
#  ('CA', 'Coolin'),
#  ('PA', 'Dewey'),
#  ('CA', 'Murray'),
#  ('VA', 'Topsham'),
#  ('PA', 'Mayfield'),
#  ('OR', 'Rotterdam'),
#  ('MI', 'Falcon'),
#  ('PA', 'Burien'),
#  ('NJ', 'Reistville'),
#  ('HI', 'Aurora'),
#  ('CA', 'Eldersburg'),
#  ('MD', 'Brownsville'),
#  ('WY', 'Lawrence'),
#  ('AR', 'Anneville'),
#  ('WV', 'Nageezi'),
#  ('RI', 'Lavalette'),
#  ('TX', 'Colonie'),
#  ('OK', 'Ahwatukee'),
#  ('CO', 'Lafayette'),
#  ('CA', 'Lyons'),
#  ('TN', 'Haymarket-Gainesville'),
#  ('ND', 'Osceloa'),
#  ('MS', 'Loring'),
#  ('WV', 'Hollywood'),
#  ('GA', 'Range'),
#  ('AZ', 'Clayville'),
#  ('OH', 'Orrock'),
#  ('TX', 'Marrietta'),
#  ('AR', 'Pacheco'),
#  ('SC', 'Tarlton'),
#  ('MN', 'Cleveland'),
#  ('IL', 'Highland'),
#  ('NY', 'Thornton'),
#  ('NY', 'Kinnelon'),
#  ('FL', 'Shunk'),
#  ('MO', 'Pompano'),
#  ('FL', 'Arkansas'),
#  ('FL', 'Rescue'),
#  ('OR', 'Newcastle'),
#  ('TX', 'Workey'),
#  ('GA', 'Arbutus'),
#  ('MO', 'Between'),
#  ('ID', 'Falcon'),
#  ('MI', 'Anahola'),
#  ('MI', 'Laplata'),
#  ('CO', 'Pgh'),
#  ('IL', 'Balmville'),
#  ('KS', 'Gladstone'),
#  ('KY', 'Amherst'),
#  ('WA', 'Sunshine'),
#  ('FL', 'Gladstone'),
#  ('CA', 'Hieleah'),
#  ('OH', 'Murphy'),
#  ('TX', 'Howland'),
#  ('WA', 'Thorton'),
#  ('OR', 'Warrington'),
#  ('HI', 'Reading'),
#  ('NY', 'Jensenbeach'),
#  ('CA', 'Trevose'),
#  ('MN', 'Athelstine'),
#  ('CA', 'Ohio'),
#  ('VT', 'Mize'),
#  ('ID', 'SC'),
#  ('MO', 'Lucas'),
#  ('FL', 'Mayfield'),
#  ('FL', 'Burien'),
#  ('HI', 'Willard'),
#  ('RI', 'Riverside'),
#  ('WV', 'Onchiota'),
#  ('CA', 'Sunderland'),
#  ('WI', 'Lamoine'),
#  ('WA', 'Brick'),
#  ('OH', 'Floristen'),
#  ('LA', 'Frederid'),
#  ('NY', 'Langdon'),
#  ('TX', 'Campo'),
#  ('WV', 'Monrovia'),
#  ('NV', 'Coward'),
#  ('IL', 'Mansfield'),
#  ('MN', 'Mosca'),
#  ('NH', 'Wilton'),
#  ('AR', 'Georgia'),
#  ('UT', 'Vernon'),
#  ('DC', 'Paincines'),
#  ('CA', 'Solitude'),
#  ('GA', 'Lawdale'),
#  ('NJ', 'Proctor'),
#  ('WI', 'Bolton'),
#  ('GA', 'Pinecrest'),
#  ('AR', 'Bloomfield'),
#  ('WA', 'Milton'),
#  ('OH', 'Mancheter'),
#  ('CA', 'Wolfe'),
#  ('OH', 'Lauderhill'),
#  ('OH', 'Pismo'),
#  ('NJ', 'Captiva'),
#  ('IN', 'Croghan'),
#  ('FL', 'Neola'),
#  ('OH', 'Hoover'),
#  ('VA', 'Hollywood'),
#  ('NJ', 'MillHeim'),
#  ('IL', 'Blanchard'),
#  ('IL', 'Tequesta'),
#  ('AZ', 'Summerlin'),
#  ('CA', 'Parkville'),
#  ('KY', 'Rangeley'),
#  ('OH', 'Woodhaven'),
#  ('IN', 'Flagler'),
#  ('NC', 'Isabella'),
#  ('TX', 'Greenville'),
#  ('PA', 'Oakland'),
#  ('HI', 'Johnstown'),
#  ('NJ', 'Placheville'),
#  ('TN', 'Hicksvllie'),
#  ('AK', 'Prue'),
#  ('CA', 'Chattaroy'),
#  ('SC', 'Hemet'),
#  ('AZ', 'Brier'),
#  ('MN', 'Knappa'),
#  ('CA', 'Graybill'),
#  ('CA', 'Harwichport'),
#  ('SC', 'Woodland'),
#  ('CA', 'Milford'),
#  ('WA', 'Aloha'),
#  ('IL', 'Sunrise'),
#  ('WA', 'Christney'),
#  ('PA', 'Rhawnhurst'),
#  ('WA', 'Indiana'),
#  ('IL', 'Gahanna'),
#  ('MI', 'Drake'),
#  ('ME', 'Union'),
#  ('MS', 'Blackville'),
#  ('KY', 'Kettering'),
#  ('NY', 'Rossmoor'),
#  ('SC', 'Tontitown'),
#  ('IN', 'Bruin'),
#  ('KY', 'Union'),
#  ('MN', 'Lanikai'),
#  ('FL', 'Brick'),
#  ('FL', 'Ashford'),
#  ('NV', 'Greenhills'),
#  ('NJ', 'Wapinitia'),
#  ('OK', 'Pierce'),
#  ('FL', 'Wildwood'),
#  ('FL', 'Fairfirld'),
#  ('OK', 'Shoreview'),
#  ('OH', 'Naco'),
#  ('CA', 'Lordsburg'),
#  ('CA', 'Gorge'),
#  ('UT', 'Sea-Tac'),
#  ('CA', 'Hasty'),
#  ('CA', 'Lacassine'),
#  ('CO', 'Willglen'),
#  ('OH', 'LosAlamos'),
#  ('OK', 'Moultonboro'),
#  ('NC', 'Woodbury'),
#  ('PA', 'Bryon'),
#  ('MD', 'Keys'),
#  ('OH', 'Bethany'),
#  ('TX', 'Lackawanna'),
#  ('WA', 'Goffstown'),
#  ('SD', 'Shoreline'),
#  ('VA', 'Urrieta'),
#  ('CT', 'Thornton'),
#  ('MS', 'Hendersonvlle'),
#  ('NC', 'Kearns'),
#  ('NJ', 'Lakeway'),
#  ('DC', 'Perryville'),
#  ('CA', 'Entiay'),
#  ('NJ', 'Coalfield'),
#  ('PA', 'Grapevine'),
#  ('NH', 'Cambrige'),
#  ('MA', 'Yavapai'),
#  ('AL', 'Newbrighton'),
#  ('TX', 'Groten'),
#  ('ME', 'Dormont'),
#  ('FL', 'Pioneertown'),
#  ('TX', 'Kendall'),
#  ('NE', 'Gaylord'),
#  ('NJ', 'Belvidere'),
#  ('TX', 'Highland'),
#  ('IA', 'Sahuarita'),
#  ('NH', 'Waves'),
#  ('CO', 'Wellington'),
#  ('MI', 'Bunn'),
#  ('TX', 'Merton'),
#  ('MN', 'Bloomington'),
#  ('HI', 'Ballard'),
#  ('MI', 'Ocala'),
#  ('PA', 'Sylvia'),
#  ('CO', 'Aberdeen'),
#  ('PA', 'I-80'),
#  ('NM', 'Austintown'),
#  ('NC', 'Espanola'),
#  ('VA', 'Alexandria'),
#  ('IL', 'Obrien'),
#  ('WA', 'Throop'),
#  ('CA', 'Crescent'),
#  ('NC', 'Plains'),
#  ('CA', 'Miramar'),
#  ('FL', 'Roxborough'),
#  ('SC', 'Portage'),
#  ('CA', 'Millard'),
#  ('NH', 'Greece'),
#  ('MD', 'Finley'),
#  ('NV', 'Wauwatosa'),
#  ('FL', 'Campton'),
#  ('NJ', 'Timmonsville'),
#  ('FL', 'Denvee'),
#  ('AR', 'Ogdensburg'),
#  ('TX', 'Hanover'),
#  ('MA', 'Trio'),
#  ('IL', 'Bray'),
#  ('AK', 'Newcastle'),
#  ('WA', 'Glencoe'),
#  ('PA', 'Adel'),
#  ('VA', 'Chesterfeild'),
#  ('KY', 'LaPorte'),
#  ('ME', 'Matinez'),
#  ('MN', 'Lantana'),
#  ('VA', 'Norwood'),
#  ('MO', 'Brinklow'),
#  ('GA', 'Hamstead'),
#  ('WA', 'Caribou'),
#  ('NY', 'Plumsted'),
#  ('CO', 'Walterborow'),
#  ('FL', 'Captiva'),
#  ('NM', 'Rachel'),
#  ('HI', 'Fildale'),
#  ('MN', 'Stringer'),
#  ('CA', 'Hoffman'),
#  ('IL', 'richmondville'),
#  ('CA', 'Cheektowaga'),
#  ('CA', 'Mdison'),
#  ('TX', 'Ruch'),
#  ('NE', 'Hamilton'),
#  ('VA', 'I-95'),
#  ('NC', 'Benson'),
#  ('CA', 'Philadelpha'),
#  ('KY', 'Oakdale'),
#  ('CA', 'Berthold'),
#  ('MO', 'Smithport'),
#  ('MT', 'Millcreek'),
#  ('ME', 'Litchfield'),
#  ('IN', 'Leaky'),
#  ('FL', 'Conrath'),
#  ('MS', 'Crane'),
#  ('CA', 'Braintree'),
#  ('MO', 'Litha'),
#  ('MO', 'Everywhere'),
#  ('FL', 'Throop'),
#  ('CA', 'Eaugalle'),
#  ('KY', 'Avon'),
#  ('VA', 'Parkside'),
#  ('OH', 'Funston'),
#  ('PA', 'Richfield'),
#  ('NY', 'Lakehills'),
#  ('NM', 'Bunn'),
#  ('NM', 'Valencia'),
#  ('TN', 'Stephan'),
#  ('FL', 'Fredriksburg'),
#  ('NC', 'Allenspark'),
#  ('WA', 'Weippe'),
#  ('AZ', 'Grandmound'),
#  ('TX', 'Sunrise'),
#  ('IL', 'Harrisville'),
#  ('OH', 'Gibralter'),
#  ('PA', 'Tridelphia'),
#  ('IN', 'Jessieville'),
#  ('FL', 'Glencoe'),
#  ('AL', 'Centerville'),
#  ('NC', 'Quinby'),
#  ('NJ', 'Jonesville'),
#  ('WA', 'Springlake'),
#  ('MO', 'Ludlow'),
#  ('AL', 'Newbury'),
#  ('WA', 'Cordell'),
#  ('CA', 'Lauderhill'),
#  ('ND', 'Bolton'),
#  ('ME', 'Lisbon'),
#  ('CA', 'Hoover'),
#  ('IL', 'Gable'),
#  ('TX', 'Trooper'),
#  ('NC', 'Irondale'),
#  ('WI', 'Palistine'),
#  ('MN', 'Hatteras'),
#  ('NY', 'Dutton'),
#  ('IL', 'Loxahatchee'),
#  ('PA', 'Mammoth'),
#  ('NY', 'Turnersville'),
#  ('FL', 'Cottenwood'),
#  ('MI', 'Luray'),
#  ('AZ', 'Fallsburg'),
#  ('IL', 'Gratis'),
#  ('OH', 'Lagrange'),
#  ('PA', 'I-70'),
#  ('OH', 'Rogers'),
#  ('FL', 'Platsmouth'),
#  ('NV', 'Rowesville'),
#  ('CA', 'Tabernacle'),
#  ('NY', 'Sunset'),
#  ('NC', 'Hazel'),
#  ('NJ', 'Ewing'),
#  ('OH', 'Westboro'),
#  ('MI', 'Roper'),
#  ('NY', 'Peoria'),
#  ('OR', 'Northport'),
#  ('HI', 'Baldwin'),
#  ('CA', 'Ramsey'),
#  ('OR', 'Milo'),
#  ('MN', 'Lehigh'),
#  ('NH', 'Parole'),
#  ('MI', 'Lyman'),
#  ('OH', 'Nelson'),
#  ('SC', 'Ramsey'),
#  ('TX', 'Nageezi'),
#  ('LA', 'Englishtown-Manalapan'),
#  ('FL', 'Longdale'),
#  ('MI', 'Goodman'),
#  ('TX', 'Wooten'),
#  ('MN', 'Huntington'),
#  ('IA', 'Brick'),
#  ('WA', 'Riverdale'),
#  ('MT', 'Halletsville'),
#  ('MI', 'Leyden'),
#  ('NM', 'Litchfield'),
#  ('GA', 'Murphy'),
#  ('UT', 'Lemitar'),
#  ('KY', 'Butte'),
#  ('WV', 'Rockledge'),
#  ('ME', 'Wahkiki'),
#  ('CA', 'Haywood'),
#  ('WA', 'DeLuz'),
#  ('VT', 'Calamine'),
#  ('PA', 'Ricelake'),
#  ('TX', 'Savanagh'),
#  ('OH', 'Mountaindale'),
#  ('PA', 'York'),
#  ('TX', 'Mechaniscville'),
#  ('SC', 'Superior'),
#  ('NH', 'Lakeway'),
#  ('MA', 'Sicklerviller'),
#  ('VA', 'Lorenzo'),
#  ('MD', 'Manalapan'),
#  ('OH', 'Salie'),
#  ('LA', 'Westboro'),
#  ('OR', 'Kingsbury'),
#  ('NY', 'Wellington'),
#  ('IL', 'Reno'),
#  ('MA', 'Austin'),
#  ('CO', 'Monnroe'),
#  ('SD', 'Dartmouth'),
#  ('AZ', 'Sherwood'),
#  ('UT', 'LaFontaine'),
#  ('IN', 'Coffeville'),
#  ('KS', 'Timmonsville'),
#  ('NY', 'Aberdeen'),
#  ('TX', 'Bend'),
#  ('GA', 'Pendleton'),
#  ('PA', 'Michicot'),
#  ('WA', 'Parma'),
#  ('SC', 'Sugden'),
#  ('ME', 'Branchburg'),
#  ('WI', 'Cardiff'),
#  ('PA', 'Westfir'),
#  ('CA', 'Oaklandon'),
#  ('SC', 'Larksville'),
#  ('PA', 'Ricetown'),
#  ('OH', 'Centerville'),
#  ('CA', 'Forebay'),
#  ('MA', 'Kenton'),
#  ('PA', 'Webster'),
#  ('WA', 'Sedona'),
#  ('MI', 'Coloma'),
#  ('VT', 'Packwaukee'),
#  ('KS', 'Hartford'),
#  ('AZ', 'Dorchester'),
#  ('LA', 'Grenville'),
#  ('CA', 'Salvo'),
#  ('WA', 'Lochbuie'),
#  ('TN', 'Wentzvillle'),
#  ('OH', 'Petosky'),
#  ('SD', 'Cibola'),
#  ('PA', 'Mcelhattan'),
#  ('HI', 'Hollywood'),
#  ('OH', 'Abiquiu'),
#  ('TX', 'Bylas'),
#  ('IL', 'Huntsvile'),
#  ('PA', 'Murray'),
#  ('FL', 'York'),
#  ('ID', 'Eva'),
#  ('MA', 'Vado'),
#  ('FL', 'Wascott'),
#  ('MN', 'Kirkwood'),
#  ('CO', 'Austintown'),
#  ('ME', 'Centerline'),
#  ('MT', 'Margate'),
#  ('CA', 'Westchester'),
#  ('MI', 'Selleck'),
#  ('UT', 'Johnsburg'),
#  ('AR', 'Jacksonville'),
#  ('AL', 'Espanola'),
#  ('NH', 'Ray'),
#  ('FL', 'Miami'),
#  ('IN', 'Jamestown'),
#  ('UT', 'Overland'),
#  ('ID', 'Esterk'),
#  ('NY', 'Wailea'),
#  ('AZ', 'Selma'),
#  ('AZ', 'Saugus'),
#  ('WY', 'Mississippi'),
#  ('KY', 'Rockhill'),
#  ('PA', 'Hailemaile'),
#  ('PA', 'Clements'),
#  ('IA', 'Springville'),
#  ('WA', 'Clayton'),
#  ('WA', 'Kissimme'),
#  ('SC', 'McMurray'),
#  ('NY', 'Cuchara'),
#  ('FL', 'Ludlow'),
#  ('CA', 'Bradford'),
#  ('TX', 'Hauula'),
#  ('WA', 'Alabama'),
#  ('NC', 'Wailua'),
#  ('FL', 'Ricetown'),
#  ('PA', 'PA'),
#  ('CA', 'Caviota'),
#  ('MA', 'Graycourt'),
#  ('WI', 'Painseville'),
#  ('UT', 'Welton'),
#  ('SD', 'Corinth'),
#  ('GA', 'Ledyard'),
#  ('SC', 'Pantego'),
#  ('WI', 'Berkley'),
#  ('CA', 'Pomona'),
#  ('FL', 'Keeneyville'),
#  ('GA', 'Stevensburg'),
#  ('PA', 'Nagshead'),
#  ('MN', 'Keaau'),
#  ('NJ', 'Lacassine'),
#  ('MA', 'Woodside'),
#  ('FL', 'Ararat'),
#  ('MI', 'Exeter'),
#  ('NJ', 'Milan'),
#  ('IA', 'Walker'),
#  ('MS', 'Wellington'),
#  ('IL', 'Duck'),
#  ('IL', 'Catawba'),
#  ('WA', 'Ovilla'),
#  ('MO', 'Strawberry'),
#  ('AZ', 'Ringold'),
#  ('OH', 'Woodbury'),
#  ('NY', 'Orient'),
#  ('UT', 'Hilldale'),
#  ('MI', 'McDonough'),
#  ('OR', 'Brickerville'),
#  ('TN', 'Kensington'),
#  ('CA', 'Countryside'),
#  ('MO', 'LaCrosse'),
#  ('MT', 'Woodhaven'),
#  ('CO', 'Tijuana'),
#  ('VA', 'Gamewell'),
#  ('DC', 'Empire'),
#  ('TN', 'Napavine'),
#  ('FL', 'Mililani'),
#  ('UT', 'Castella'),
#  ('GA', 'Salvo'),
#  ('NY', 'Escawtawpa'),
#  ('NV', 'Irondequoit'),
#  ('CA', 'Lagrange'),
#  ('OH', 'Carlyss'),
#  ('MI', 'Southpark'),
#  ('GA', 'Rubidoux'),
#  ('IL', 'Cleveland'),
#  ('AZ', 'Zim'),
#  ('IN', 'Chesterfield'),
#  ('CO', 'LaPorte'),
#  ('NY', 'Newburg'),
#  ('FL', 'Dunwoody'),
#  ('SC', 'Lagrange'),
#  ('TX', 'Guilford'),
#  ('FL', 'Sells'),
#  ('CA', 'Neptune'),
#  ('MD', 'Forestill'),
#  ('NY', 'Kibler'),
#  ('TX', 'McGill'),
#  ('TX', 'Reno'),
#  ('CA', 'Urbana'),
#  ('NC', 'Howell'),
#  ('CA', 'Oakhill'),
#  ('CO', 'Harrisonville'),
#  ('MN', 'Randolph'),
#  ('PA', 'Huttonsville'),
#  ('MI', 'Ridgeway'),
#  ('MT', 'Superior'),
#  ('FL', 'Lakeside'),
#  ('AR', 'Sarles'),
#  ('WA', 'Elsmere'),
#  ('ID', 'Greenwater'),
#  ('MO', 'Galloway'),
#  ('FL', 'Millcreek'),
#  ('OH', 'Sidney'),
#  ('CA', 'Aurora'),
#  ('AZ', 'unkown'),
#  ('CO', 'Como'),
#  ('CA', 'Potter'),
#  ('AZ', 'Tishimingo'),
#  ('NY', 'Jarratt'),
#  ('KY', 'Laclede'),
#  ('CO', 'Avon'),
#  ('CO', 'Industry'),
#  ('UT', 'LaGrange'),
#  ('VA', "O'Brien"),
#  ('ME', 'Interstate'),
#  ('NY', 'Wicomico'),
#  ('OK', 'Desert'),
#  ('NH', 'Cistern'),
#  ('VA', 'Gary'),
#  ('WI', 'Ashe'),
#  ('UT', 'York'),
#  ('KS', 'Mauriceville'),
#  ('ME', 'Gainseville'),
#  ('NE', 'Ardonia'),
#  ('OH', 'Lewisburg'),
#  ('MS', 'Parma'),
#  ('MN', 'Calhoun'),
#  ('MI', 'Burien'),
#  ('FL', 'Saticoy'),
#  ('IL', 'Windham'),
#  ('NY', 'Manchester'),
#  ('NY', 'Kettering'),
#  ('AZ', 'Bellevue'),
#  ('CA', 'Edwards'),
#  ('NE', 'Sax'),
#  ('CA', 'Kenmore'),
#  ('VA', 'Weston'),
#  ('VT', 'Lockwood'),
#  ('AL', 'Eaton'),
#  ('CA', 'Centerville'),
#  ('NC', 'Buford'),
#  ('SD', 'Wenksville'),
#  ('CA', 'Newbury'),
#  ('NC', 'Fitchburg'),
#  ('FL', 'Passaconway'),
#  ('GA', 'Baker'),
#  ('OR', 'Buckingham'),
#  ('GA', 'Lagrange'),
#  ('MI', 'Downer'),
#  ('ME', 'Algiers'),
#  ('NC', 'Chennai'),
#  ('CA', 'Highridge'),
#  ('TX', 'Fillmore'),
#  ('WV', 'Centennial'),
#  ('OH', 'Ahmadi'),
#  ('ID', 'Burien'),
#  ('GA', 'Pittston'),
#  ('NC', 'Merriville'),
#  ('FL', 'Hayfork'),
#  ('CO', 'Otsego'),
#  ('FL', 'Mainstee'),
#  ('OH', 'Parker'),
#  ('MA', 'Eastvale'),
#  ('NY', 'Bratenhaul'),
#  ('NC', 'Stewartstown'),
#  ('FL', 'Stella'),
#  ('NJ', 'Piranguinho'),
#  ('NY', 'Lanson'),
#  ('NM', 'Rescue'),
#  ('AL', 'Gorham'),
#  ('TX', 'Atascosita'),
#  ('IA', 'Coolridge'),
#  ('PA', 'Miramar'),
#  ('VA', 'Burnside'),
#  ('HI', 'Waipio'),
#  ('CA', 'Sterling'),
#  ('UT', 'Westover'),
#  ('NC', 'Lenoir'),
#  ('NY', 'Stockbridge'),
#  ('MO', 'Kansas'),
#  ('OH', 'Linthicum'),
#  ('ID', 'Crystal'),
#  ('WA', 'Gallatin'),
#  ('PA', 'Margate'),
#  ('PA', 'Pittsburg'),
#  ('OK', 'Arden'),
#  ('NV', 'Murray'),
#  ('FL', 'Shapleigh'),
#  ('MI', 'Brick'),
#  ('HI', 'Devore'),
#  ('TX', 'Daytona'),
#  ('TN', 'Saugus'),
#  ('WA', 'Westport'),
#  ('NC', 'Kahana'),
#  ('AK', 'Shoreline'),
#  ('PA', 'Altomont'),
#  ('UT', 'Lennox'),
#  ('NY', 'Cleora'),
#  ('CO', 'Hamilton'),
#  ('IL', 'Highwood'),
#  ('AZ', 'Glennallen'),
#  ('CA', 'Menands'),
#  ('HI', 'Lake'),
#  ('FL', 'Tinsley'),
#  ('CA', 'Unknown'),
#  ('OK', 'Farragut'),
#  ('IL', 'Larkesville'),
#  ('ME', 'Fullerville'),
#  ('UT', 'Bellington'),
#  ('CA', 'Tri-Cities'),
#  ('MI', 'Wendover'),
#  ('OR', 'Moreland'),
#  ('OH', 'Poinciana'),
#  ('WI', 'Edina'),
#  ('NY', 'Bluffdale'),
#  ('TX', 'Kenna'),
#  ('NM', 'Tukwilla'),
#  ('PA', 'Braintree'),
#  ('NC', 'Oakville'),
#  ('CA', 'Rome'),
#  ('NH', 'Belmont'),
#  ('CA', 'Woodbury'),
#  ('NY', 'LaPorte'),
#  ('MS', 'Lesslie'),
#  ('IL', 'Bloomington'),
#  ('OR', 'Yah-ta-hey'),
#  ('MO', 'Oklahoma'),
#  ('VA', 'Centennial'),
#  ('PA', 'Randsburg'),
#  ('WY', 'Silverhilll'),
#  ('OH', 'Camargo'),
#  ('MD', 'Winslow'),
#  ('NJ', 'Oklahoma'),
#  ('NC', 'Ritter'),
#  ('KS', 'Margate'),
#  ('OK', 'Brownsville'),
#  ('MN', 'Moultonboro'),
#  ('AL', 'Lavale'),
#  ('WA', 'Wilderville'),
#  ('FL', 'Margate'),
#  ('UT', 'Roswell'),
#  ('AZ', 'Ellensberg'),
#  ('OR', 'Rachel'),
#  ('WI', 'Moore'),
#  ('NY', 'Lynnville'),
#  ('NM', 'Kaanapali'),
#  ('WA', 'Sutcliff'),
#  ('CA', 'Cisco'),
#  ('WA', 'Jamaica'),
#  ('OK', 'Creston'),
#  ('CA', 'Hollandale'),
#  ('NY', 'Avon'),
#  ('OH', 'Yankeetown'),
#  ('NJ', 'Greenfield'),
#  ('NC', 'Hamburg'),
#  ('ID', 'Niles'),
#  ('PA', 'Tabernacle'),
#  ('CA', 'Elk'),
#  ('MN', 'Kabetogama'),
#  ('TX', 'Setauket'),
#  ('ME', 'Redbank'),
#  ('OH', 'Viera'),
#  ('WA', 'Ruso'),
#  ('ID', 'Lemitar'),
#  ('FL', 'Haleiwa'),
#  ('PA', 'Bellefonte'),
#  ('NM', 'Mustang'),
#  ('AK', 'Falcon'),
#  ('TX', 'Maui'),
#  ('NJ', 'Melbourne'),
#  ('MI', 'Edgewood'),
#  ('OR', 'Tijuana'),
#  ('OR', 'Helena'),
#  ('WI', 'Louisiana'),
#  ('FL', 'Bonaie'),
#  ('MD', 'Shawville'),
#  ('OH', 'Hollywood'),
#  ('IN', 'Plum'),
#  ('ME', 'Harmony'),
#  ('SC', 'Sidney'),
#  ('HI', 'Hendersville'),
#  ('LA', 'Wakonda'),
#  ('IN', 'Northlake'),
#  ('CA', 'Plum'),
#  ('CA', 'Beeville-Kennedy'),
#  ('OR', 'LaPorte'),
#  ('NY', 'McDermott'),
#  ('NJ', 'Sunflower'),
#  ('TN', 'Aloha'),
#  ('NC', 'Chihlowie'),
#  ('WV', 'Yarmouth'),
#  ('NY', 'Luray'),
#  ('WI', 'Winterset'),
#  ('CA', 'Fairlawn'),
#  ('WI', 'Crestline'),
#  ('NY', 'Luling'),
#  ('HI', 'Perth'),
#  ('AK', 'Georgia'),
#  ('MA', 'Preble'),
#  ('CA', 'Benson'),
#  ('VA', 'Atascocita'),
#  ('GA', 'Wilmont'),
#  ('MA', 'Summerlin'),
#  ('HI', 'Carrie'),
#  ('ME', 'Stoneham'),
#  ('WA', 'Yardley'),
#  ('CT', 'Pink'),
#  ('WA', 'Fontanna'),
#  ('LA', 'Hollywood'),
#  ('CA', 'Bakesrsfield'),
#  ('WA', 'Worcester?'),
#  ('MA', 'Deforest'),
#  ('NY', 'Lyman'),
#  ('OK', 'Nassau'),
#  ('OR', 'Avon'),
#  ('NC', 'Wellington'),
#  ('MI', 'Inverness'),
#  ('WY', 'Knappa'),
#  ('CA', 'Chicago'),
#  ('WA', 'Kiluea'),
#  ('CA', 'MacArthur'),
#  ('MD', 'DeMotte-Roselawn'),
#  ('CA', 'Lyndon'),
#  ('CA', 'Allenspark'),
#  ('CA', 'Hopulikit'),
#  ('OH', 'Roscoe'),
#  ('AZ', 'Rinard'),
#  ('PA', 'Weybridge'),
#  ('PA', 'Salvo'),
#  ('SC', 'Winchester'),
#  ('KS', 'Superior'),
#  ('IA', 'Clermont'),
#  ('NJ', 'Luka'),
#  ('IL', 'Lehigh'),
#  ('PA', 'Volujntown'),
#  ('FL', 'Superior'),
#  ('WA', 'Robertsdale'),
#  ('ID', 'Massachusetts'),
#  ('FL', 'Damiansville'),
#  ('FL', 'Liberty'),
#  ('AL', 'Hendersom'),
#  ('UT', 'Mohave'),
#  ('CO', 'Palmersville'),
#  ('NC', 'Martinez'),
#  ('NJ', 'Beloit'),
#  ('NY', 'Holland'),
#  ('CA', 'Suffield'),
#  ('AR', 'Sunfield'),
#  ('MO', 'Wickliff'),
#  ('IN', 'Fridley'),
#  ('WA', 'Moore'),
#  ('OH', 'Poipu'),
#  ('NC', 'Tylersport'),
#  ('MI', 'Ammon'),
#  ('MT', 'Bluebell'),
#  ('SC', 'Lafollette'),
#  ('CO', 'Williamsville'),
#  ('OH', 'Arizona'),
#  ('CO', 'Northglenn'),
#  ('LA', "Kea'au"),
#  ('VT', 'Goshen'),
#  ('HI', 'Central'),
#  ('PA', 'Fairview'),
#  ('ID', 'Dunnsville'),
#  ('KY', 'Pearl'),
#  ('CO', 'Clinchport'),
#  ('PA', 'Ashton'),
#  ('UT', 'Downingtown'),
#  ('WA', 'Manalapan'),
#  ('WA', 'Hurley'),
#  ('AR', 'Corcoran'),
#  ('FL', 'Heber'),
#  ('NV', 'Cushing'),
#  ('NJ', 'Aurora'),
#  ('OR', 'Deptford'),
#  ('MA', 'Longview'),
#  ('IN', 'Barber'),
#  ('AL', 'Glenndale'),
#  ('FL', 'Greenfield'),
#  ('NV', 'Pittsburg'),
#  ('NM', 'Paincines'),
#  ('UT', 'Cheektowaga'),
#  ('NY', 'Edina'),
#  ('PA', 'Goldtown'),
#  ('NH', 'Oklahoma'),
#  ('AK', 'Valentine'),
#  ('TX', 'Eastvale'),
#  ('FL', 'Lasalle'),
#  ('WA', 'Rudy'),
#  ('AZ', 'Knowlton'),
#  ('PA', 'Gibralter'),
#  ('NJ', 'Roseau'),
#  ('MD', 'Rosemont'),
#  ('OR', 'Frenchtown'),
#  ('AZ', 'Landover'),
#  ('MN', 'Sautee'),
#  ('WA', 'Hooper'),
#  ('CT', 'Dawson'),
#  ('MO', 'Kenmore'),
#  ('IL', 'Colwell'),
#  ('NM', 'Dunnsville'),
#  ('NY', 'Lynxville'),
#  ('NY', 'Vernon'),
#  ('UT', 'Blaine'),
#  ('MI', 'Brinklow'),
#  ...}

# %%
# First, filter the DataFrame based on the conditions for missing coordinates
missing_coords = USA_ufo_data[
    pd.notna(USA_ufo_data['city']) & 
    pd.notna(USA_ufo_data['state']) & 
    pd.isna(USA_ufo_data['city_latitude']) & 
    pd.isna(USA_ufo_data['city_longitude'])
]

# Now filter out cities that contain more than one word (i.e., cities with spaces)
missing_coords_and_single_word_cities = missing_coords[missing_coords['city'].apply(lambda x: len(x.split()) == 1)]

missing_coords_and_single_word_cities
# Out:
#            city state           date_time    shape    duration  \
# 4        Peoria    NY 2009-03-15 18:00:00    cigar   2 minutes
# 18       Leyner    CO 2019-08-09 20:22:00    light  20 minutes
# 19     Catalina    AZ 2019-08-09 20:30:00    cigar  40 seconds
# 27         Wall    NJ 2015-06-15 22:00:00    light    1 minute
# 41       Golden    TX                 NaT     disk   3 seconds
# ...         ...   ...                 ...      ...         ...
# 88107   Harmony    FL 2019-10-01 21:20:00  chevron  20 seconds
# 88112   Hayfork    CA 2019-10-02 01:00:00  unknown   3 minutes
# 88113  Limerick    PA 2019-10-02 03:26:00   circle  20 seconds
# 88114  Limerick    PA 2019-10-02 03:26:00   circle  20 seconds
# 88117   Hayfork    CA 2019-10-02 12:00:00      NaN   7 minutes
#
#                                                     text     posted  \
# 4      In Peoria, Arizona, I saw a cigar shaped craft... 2019-04-18
# 18     There where 4 bright lights in a shape of a di... 2019-08-23
# 19     My wife and I were taking our usual evening st... 2019-08-23
# 27     4 bright lights weaving in between one another... 2019-08-23
# 41     children see flying saucer in small East Texas...        NaT
# ...                                                  ...        ...
# 88107  I was talking on the phone laying on my front ... 2019-10-04
# 88112  Don't care it happend A craft came over us the... 2019-10-04
# 88113  ((NUFORC Note:  Witness does not include any d... 2019-10-04
# 88114  I was driving to work and I’m the only one on ... 2019-10-04
# 88117  On history channel there should be a contact #... 2019-10-04
#
#        city_latitude  city_longitude  time_diff_minutes  word_count
# 4                NaN             NaN          5306760.0         211
# 18               NaN             NaN            18938.0          36
# 19               NaN             NaN            18930.0          77
# 27               NaN             NaN          2201880.0          37
# 41               NaN             NaN                NaN         267
# ...              ...             ...                ...         ...
# 88107            NaN             NaN             3040.0         112
# 88112            NaN             NaN             2820.0          26
# 88113            NaN             NaN             2674.0          13
# 88114            NaN             NaN             2674.0         177
# 88117            NaN             NaN             2160.0          14
#
# [5328 rows x 11 columns]

# %% [markdown]
# takes wayyyyy to long (waited 25 mins before I gave up :/)

# %%
# # Cache to store previously fetched coordinates
# cache = {}

# # Iterate over rows and update longitude and latitude where needed
# for index, row in missing_coords_and_single_word_cities.iterrows():
#     # Check if city and state are not NaN and if latitude or longitude are NaN
#     if pd.notna(row['city']) and pd.notna(row['state']) and pd.isna(row['city_latitude']) and pd.isna(row['city_longitude']):
#         # Get coordinates using Geopy
#         latitude, longitude = get_coordinates(row['city'], row['state'], cache)
        
        
#         missing_coords_and_single_word_cities.at[index, 'city_latitude'] = latitude
#         missing_coords_and_single_word_cities.at[index, 'city_longitude'] = longitude

#         # Add a delay to avoid overloading the API
#         time.sleep(1)  # Adjust the sleep time as needed
        
# # Output updated DataFrame or inspect
# missing_coords_and_single_word_cities

# %% [markdown]
# #### The Dreaded Duration Column

# %% [markdown]
# getting an idea of what the duration texts look like

# %%
duration = set()

for duration_len in ufo_data['duration']:
    duration.add(duration_len)

duration
# Out:
# {'Few Seconds',
#  '1 minute+',
#  '1 minute (each light)',
#  'Possible Abduction',
#  '2to3min',
#  'approx. 15-30sec',
#  'Multiple Events',
#  '3 x 20-30 sec./each',
#  '9',
#  '5 to 20 seconds',
#  'AROUND 10 MIN',
#  '8-10 min',
#  '30 min-1hr',
#  'about 1min',
#  '9:30ish',
#  'The photo.',
#  'About 1 minute',
#  '20 secnds',
#  'under 10 seconds',
#  '5  min.',
#  'about 1-2 minutes',
#  's minutes',
#  '10/15 sec',
#  '5-6 min',
#  'circa 8 seconds',
#  'couple of minutes',
#  'since Dec 5th',
#  'four to five seconds',
#  '7-9 seconds',
#  'aprox. 1:30 sec',
#  '5min',
#  '25 minutes or so',
#  '5?min',
#  '4 - 5 secs',
#  '10.5 minutes',
#  '1min/14 secs',
#  '30 MIN,',
#  '5-10mins',
#  '10 minutes or so',
#  'Ongoing right now',
#  '26 mins',
#  'not seen',
#  '15 ninutes',
#  '>1 hr',
#  'about 20-30 seconds',
#  '60 min',
#  '00:44',
#  '1 & 1/2',
#  '95 seconds',
#  '10 segundos',
#  '25 mnutes',
#  '10 15 min',
#  '25-35 seconds',
#  'about half a second',
#  'approx=3-4hrs',
#  '5 - 7 seconds',
#  '10 Min',
#  '35+ minutes',
#  'apx. 15 mins',
#  '1hr+',
#  'Seconds??',
#  'city',
#  '1 hour at time of report',
#  '45secs',
#  '3:08',
#  '4 10 mins',
#  'roughly 45 minutes',
#  'dident stop',
#  '00:00:01',
#  '1.5 Hours',
#  '3+',
#  '4 - 6 minutes',
#  '1min+/-',
#  'About 30 sec.',
#  '45 Mintues',
#  '1 to 2 min',
#  '1minute +',
#  '6-8 min',
#  'N/R',
#  'Couple minutes',
#  '0ne hour and plus',
#  'All Summer',
#  'about four minutes',
#  'continously',
#  'visiting',
#  '5 minutes approx',
#  'less than a min.',
#  'approx 30 to45 minutes',
#  'Flyby approx 20 sec.',
#  '1min 50 secs',
#  '1 min 30 seonds',
#  '2.5min.',
#  '18 min.',
#  '>1 year',
#  '10 minutes & running',
#  '13 Mins',
#  '30-40 sec.',
#  '20 seconds (each)',
#  '1:41',
#  '1-2 Sec',
#  '10 Mins',
#  '5-10 mins. ea.',
#  ':30 minutes',
#  '45-90 minutes',
#  'three - five minutes',
#  'at least one hour',
#  '4 - 5 Seconds',
#  '30 Mins +',
#  '1hr 45mins',
#  ':0030',
#  '00:25',
#  '2-3 Min.',
#  '5 seconds (twice)',
#  '70 seconds',
#  '2-5 se onds',
#  '3,4 SECS',
#  'apprx. 3-5 min',
#  '2 hours',
#  '1-3 min.',
#  '10s; 30m',
#  '20 Mins',
#  '1- 1.5 hr',
#  '30 sec / 10 minutes',
#  '10 MINUTES',
#  'Mere seconds',
#  'mere seconds',
#  'couple minutes',
#  '10-15 min',
#  'sporadic 5 seconds severa',
#  '10-13 minutes',
#  'UPDATE',
#  '2 minuites',
#  '5:00 minutes',
#  'One Hour',
#  '1 to 2 seconds',
#  '5minutes',
#  '10 to15 seconds',
#  '35 sec.',
#  'night sky',
#  'Not known',
#  '45 min.',
#  '10 to 12 min.',
#  '1 min apox',
#  '1 minute',
#  'UNKNOWN',
#  '2-3 mintutes',
#  '90 to 120 seconds',
#  '7 mi',
#  'about 7 min',
#  '70sec',
#  '5 Min',
#  '15-30min',
#  '80 min',
#  '40 min. per.',
#  'North-east',
#  '1.30 Minutes (est.)',
#  'Until sunrise',
#  'About 20 seconds',
#  'approx. 1 1/2 hours',
#  '5 plus min',
#  'Nightly now',
#  'Half hour',
#  '2 or 4 minutes',
#  '10 min or less',
#  '2 minutes (+/- 15 seconds',
#  '1sec',
#  'Moves around',
#  'over 5 min.',
#  'one hour or more',
#  '8:30-8:36',
#  '3-5 Sec',
#  '4min',
#  'stell',
#  '1.5hours',
#  'over an hr in a half',
#  '5-7 minutess',
#  '10 to15 sec',
#  '~30 sec.',
#  '~3 Mins',
#  '15 SECONDS',
#  'LESS THAN 30 SEC',
#  '4-5sec/1min',
#  '3 - 5 Minutes',
#  '8minutes',
#  'Continous',
#  '45 MIN',
#  'apprx. 5 min.',
#  '4:47',
#  '1:30 secs,',
#  'SEA PORT VILLAGE',
#  '~3-5 seconds',
#  '30 + minutes',
#  'approx 2hrs',
#  '10seconds',
#  '10 mintutes',
#  'BIG GLOWING RED MOON',
#  '30 sc',
#  '15-30 minute',
#  '5 minutes maybe longer',
#  'less than 30sec',
#  'about 7 min.',
#  'Slowly',
#  'Five Minutes',
#  'one day',
#  'uknown',
#  'about 10 secs.',
#  '~15 seconds',
#  'hour and half',
#  'around 30 seconds',
#  '1 Hour',
#  '88 seconds',
#  '10 minuti',
#  '.5 SEC',
#  '2 to 5 minutes',
#  '30 min or more',
#  'few second',
#  '7 to 9 sec.',
#  '6:28',
#  '3:52',
#  '10-15 min.',
#  '2 hours 10 mins',
#  'l5 minutes',
#  '30 TO 40 SEC',
#  'Lake Murray',
#  'short',
#  '1-2 years',
#  '45seconds',
#  '20 min,',
#  '2to 3 min',
#  '5-6 hrs per night',
#  '1 1/2 hrs',
#  'not sure,maybe 2 hours',
#  '1 1/2 - 2 mins',
#  '<1 min',
#  'about half a minute',
#  '02:30',
#  '35 Mins',
#  'Still going on',
#  '10min',
#  '20:15',
#  'all evening',
#  '21 minutes',
#  'a few minutes?',
#  '1+ minute',
#  'witnessed 5 minutes',
#  '1 to 2 mins',
#  '3-5 seconds',
#  '38 minutes to observe',
#  '3- 5 minutes',
#  'Not Known',
#  '10s',
#  'Too scared to keep observ',
#  '20 minutes+',
#  '1 hour(approx)',
#  '11:09',
#  '10Minutes',
#  '60 to 90 seconds',
#  '1 second +/- 0.5 Sec',
#  '~5 hours?',
#  'Every Night, all night un',
#  '1:14',
#  '3 TO 5 MIN',
#  '20-30mins',
#  '1 minute, 45 sec.',
#  '4th of July',
#  'Single picture',
#  'Google earth',
#  '4 to 5 mins',
#  '30 minutes to 1 hour',
#  '2 minutes?',
#  '~1 minute+',
#  'severl minutes',
#  '4 minutes 10 seconds',
#  '10:00 minutes',
#  'empire state building',
#  '20 seconds?',
#  'fl',
#  '90-120seconds',
#  '39 minutes',
#  '1/2 hr',
#  'During the night',
#  'still happening as I writ',
#  '@1 minute',
#  '1 hour 45 minutes',
#  '1100',
#  '7 to 10 min.',
#  'power line',
#  '10 monutes',
#  '5hours 45 minutes',
#  '03:00',
#  '45 minutes; still there',
#  '38mn',
#  'at least 1 hour',
#  'Since 12:30am',
#  '23:30 till present time 0',
#  '1/1 minutes',
#  '21 years',
#  '1.5+ hours',
#  '11 seconds',
#  '2.00 mins.',
#  'Afternoon',
#  '45 seconds to One minute',
#  '~3 minutes.',
#  '50 Seconds',
#  '2 mins or less',
#  '20+ secs.',
#  '12:00 to 3:00',
#  'Brief',
#  '65-70 seconds',
#  '1/400 second',
#  '07:30',
#  'disk',
#  '~25 seconds',
#  '3 hours?',
#  '20-22 seconds',
#  '1.2 minutes',
#  'one and a half minutes',
#  '25 MINUTES',
#  '<30 seconds',
#  'Viewed 5 minutes',
#  '1/8 of 1 second',
#  'Less than 5 minutes',
#  '23:40',
#  '15 minits',
#  '40 secs',
#  'fly by a few seconds',
#  '5 Minutes (apporx)',
#  '2,minutes',
#  'up to 5 minutes',
#  'hour and a half',
#  'walking dog',
#  '36 seconds',
#  '18 hours',
#  'one second',
#  'about 1 second',
#  '1.14',
#  '1-2 minutes',
#  '8 minutes approx.',
#  '7 days straight',
#  'dont know',
#  'approx. 2-3 min?',
#  'A half an hour',
#  '1-1 1/2 hours',
#  'Before School',
#  '5 min or less',
#  'One hour plus',
#  '-5min',
#  '>3 minutes',
#  '4.5 Hours',
#  '30 minutes (and counting)',
#  'under 1 minute',
#  '35 Minutes',
#  '4-6sec.',
#  '5 sec. app.',
#  '3-4 MIN',
#  "it's happening",
#  '15 to 30 seconds',
#  '2 to 4 seconds',
#  '10 - 15 SECONDS',
#  'hovering until we past it',
#  'A second',
#  '10-12 seconds',
#  '10-15 Minutes',
#  'Sky',
#  '21:30',
#  '3 mins and continued...',
#  'A few Minutes',
#  'Lasted until I had to go ',
#  'Still going',
#  'Several seconds',
#  '25:00',
#  '20 to 30 sec',
#  'ten minutes (twice)',
#  '12:00 am',
#  '2 minutes (each)',
#  '5 seconds apart',
#  '50-70 seconds',
#  '15 Min.',
#  'About 5 Mins long',
#  '1/2 HOUR',
#  '18:22',
#  'around 1 min 45 sec',
#  '--',
#  '60 SECONDS',
#  '5 minutes; perhaps a litt',
#  'less than 10 seconds',
#  '1 or 2 minutes',
#  'Deer Camera',
#  '60 seconds ?',
#  '@15 seconds',
#  'Moments',
#  '001',
#  'aound 5 min.',
#  '6 Seconds',
#  'Probably around 10 second',
#  '21:26 - 21:28 2 seconds',
#  '1-2mins',
#  'Approxamatly 2 minutes',
#  '25 minute',
#  '4 Minute',
#  '1HR 30MIN',
#  'Aprox 3 Mins.',
#  'at least 15 minutes',
#  'Approx 1-2 min',
#  '2-3 mins',
#  '39 min',
#  ':30 seconds',
#  '1:29',
#  '<20 minutes',
#  'Basically, all night',
#  'I hour',
#  'still ongoing',
#  '20-25 seconds',
#  'Minutes (2 sightings)',
#  '46 seconds',
#  'Approximately 1 minute',
#  '2-6 seconds',
#  '5 senconds',
#  '3-7 seconds',
#  '43 mins',
#  '3 minutes 20 seconds',
#  'Forty minutes',
#  '40min.',
#  '25 min',
#  '30 + min',
#  '6 to 10 sec.',
#  'less that a minute',
#  '45sec. - 1min.',
#  '5 - 10 Seconds',
#  'Few Days',
#  '1 1/2 minute',
#  '2-3 seconds twice about 2',
#  'one minute',
#  '10MIN, TO 15, MIN',
#  '2 horas',
#  '1.5 - 2.5 minutes',
#  '1min and a half',
#  '5-8 MIN',
#  '3-4  minutes',
#  '4-5 secs',
#  'About Three Minutes',
#  'aprox 2 min.',
#  '30 +',
#  '1.0 hours',
#  'sighting',
#  'quick',
#  '15 seconds then 30 minute',
#  '1.45 hours',
#  '3:36',
#  '20 minutess',
#  '2 OR 3 SECONDS',
#  '2.5 days',
#  '1 segundo',
#  '5 + minutes',
#  '60 second',
#  'about 10min',
#  '2 to 4 hours',
#  '5:00-5:30',
#  'about 1 min',
#  '6+ hours',
#  '0ne minute',
#  '4.5 hrs',
#  '30 Seconds or so',
#  '<20 seconds',
#  '5+minutes',
#  '7min',
#  '0:00=1:00',
#  '19:35',
#  ':30',
#  '1:27',
#  'Over 1 hour 15 mins',
#  '9-15 seconds',
#  'Approx. 40 sec.',
#  '15 minutes (appx)',
#  '3 -4 sec',
#  '5s-10s',
#  'app 3 mins',
#  '30- 1 min',
#  '5 to 7 min.',
#  'a half hour',
#  '2 miutes',
#  'Outside',
#  '4-5  minutes',
#  '45-180 seconds',
#  '09:55',
#  '5 MINS',
#  'On going',
#  '00:00:10',
#  '45 sec.',
#  'Ewing Cemetery',
#  '5 mins or more',
#  '~4 seconds',
#  'Approx 2 seconds',
#  '1:08',
#  'most nights',
#  'Noticed from dusk to dawn',
#  'aprox 30 seconds',
#  '2 1/2 hours or more',
#  '3:00min',
#  '~30 minutes',
#  'Driving',
#  '25-30 seconds',
#  '30sec-1 min',
#  '1 minute-2mins',
#  '11/2-2 minutes',
#  '2 hr 30 min',
#  'over an hour',
#  '3-5+- minutes',
#  '30 mimutes',
#  '30 min.',
#  '7-10 seconds',
#  '< 10min',
#  '01 min',
#  '>3-4 hours',
#  'not determined',
#  'continues',
#  'at home',
#  '~60 minutes',
#  '0:19- 0:37',
#  '3-4 minuites',
#  '20 seconds +',
#  '10-15mins',
#  '35min;',
#  '00:30:00',
#  'about a minute and a half',
#  'Several Hours',
#  'aliens',
#  '15+ Mins.',
#  'ten min',
#  'About 3 hours',
#  '2.30',
#  '4 minutos',
#  '2-3 hours/1-2 Wks',
#  '5 sec.',
#  '10',
#  '25 - 30 mins',
#  '3 to 4 min.',
#  '80 seconds',
#  '10 minutes now',
#  '1 + HOURS',
#  ':27',
#  '~35 minutes',
#  '1 to 2 minutes',
#  '5m',
#  '1 miute',
#  '10-minutes',
#  'O',
#  'two -tree minuts',
#  '2-3mins',
#  'Approx. 90 secs',
#  '20 minutes and ongoin',
#  'Photo time',
#  'Approx 30 min',
#  '27sec',
#  'Approx. 15 sec.',
#  '3-4 sec.',
#  'Unknown',
#  '20 MINUTES',
#  '10 to 20 seconds',
#  'approx 2 min',
#  '4 - 5 minutes',
#  'Longer than 5 minutes',
#  'minets ?',
#  '1hr. 30 minutes',
#  'About a min',
#  '2.5 hour',
#  'approx 10 seconds',
#  'hours on and off',
#  'photo only',
#  '15min+',
#  '2 hours now',
#  'less 2min',
#  '20 second',
#  '22:45',
#  '15 days plus',
#  '1 and 1/2 minute',
#  '3.00 min',
#  '3-hours',
#  '5-6 min.',
#  '00:08',
#  '3 Min',
#  '30 minutes on and off.',
#  '24 seconds',
#  '40 minutos',
#  'Ongoing now',
#  '15/60mins',
#  '3 minutes...',
#  'ongoing',
#  '<> 15 minutes',
#  '2 mins 12 seconds',
#  '2-4 minutes',
#  '00:14',
#  '20m',
#  'continuousu',
#  'every hour  lasting for 5',
#  'all day',
#  '4-5 mins.',
#  'about 45 minutes from the',
#  'Still Present',
#  'approx 20-30 mins',
#  '21:33',
#  'Seven Minutes',
#  'driving from monticello t',
#  'at least 15 mins',
#  '3 -4 min',
#  '15 Minutes +',
#  '22:00-22:30',
#  'five second or less',
#  'Approx 1 minute',
#  '1.5 min.',
#  '08:00 PM',
#  'approx 1 1/2 mins',
#  '7 secondds',
#  '1.5 min',
#  '12min',
#  'minutes at least',
#  '15-seconds',
#  'kept going',
#  'A couple of minutes',
#  '1.5 to 2,5 seconds',
#  '1 Second?',
#  '15/20 seconds',
#  'single photo',
#  'Approx 5 min',
#  'heading home from work',
#  "2'",
#  '5 minutes (2 Events)',
#  'Approx.3 Hrs.',
#  '~15-25 minutes',
#  '.5 seconds',
#  'not sure lost sight behin',
#  '>6 minutes',
#  'Livernois',
#  '<10 sec.',
#  'five to ten seconds',
#  '5 days +',
#  '14 nights',
#  'foggy',
#  '0-10 mins.',
#  'Three minutes',
#  '3 hours',
#  '1-5 minutes',
#  '83 seconds',
#  '<1 sec.',
#  '1 hr',
#  '2-3 sec',
#  '!minute',
#  '300',
#  '>20 minutes.',
#  'aprx 20min',
#  '15:00/24:00',
#  '01-02min',
#  '10 minutes (?)',
#  'watched for 20 min.',
#  '>20-40 minutes',
#  'less than 3 seconds',
#  '<40 seconds',
#  '8',
#  '4-5 (?) seconds',
#  'Almost every night',
#  'occuring now',
#  '30-60 mintues',
#  '~8 hours+',
#  '45-90 seconds',
#  '10-15 second',
#  'about 7 seconds',
#  'very short',
#  '1.30 seconds',
#  '5-6 minutes',
#  '45-60 seconds',
#  '45-hour',
#  'not sure exactly',
#  'ca: 1min',
#  '.5',
#  '5 sec - Ten minutes?',
#  '15 MInutes',
#  'Aproximately 2 mins',
#  'only a few seconds, it wa',
#  '1 min, 38 sec',
#  '5-on going',
#  '30min',
#  '5;00',
#  '<1m',
#  '2hours or more',
#  '30 to 40 mins',
#  '15 secs.',
#  '10 mintes',
#  '0.00',
#  '3 MINUTES',
#  'outer structure spinning ',
#  '1O minutes',
#  'Just over a Minute',
#  '7-8 mins',
#  'est.1 minute',
#  '10mins',
#  'I saw the last minute of ',
#  '23:41',
#  '2-3min.',
#  '1 Hour plus',
#  'flashing lights',
#  'ten+ minutes',
#  '1 min. 2 secs',
#  'A few moments',
#  '1 second.',
#  '20 MINS',
#  '3.000',
#  '34 Days',
#  'each event was witnessed ',
#  '15min',
#  '2hrs, 40 min',
#  'about 3 sec',
#  '>5-10 minutes',
#  '30 secopnd',
#  '2.min',
#  '1min 45secs',
#  '15:00/20:00',
#  'A minute or so.',
#  'Ongoing',
#  '21 seconds',
#  'about 45 minutes',
#  'few secounds',
#  '80secs',
#  '1.25 minutes',
#  'Varies',
#  '~20-30',
#  'Miramar',
#  '30secs',
#  '1 hour total',
#  '5 minutres',
#  'Took off in da sky',
#  '2 to 3 minutes',
#  'Sheriff station on imper',
#  '10 - 12 seconds',
#  '1 picture',
#  'about 3 min',
#  'seconds or minutes',
#  '1 - 2 seconds',
#  '2.5 min',
#  '5 TO 7 MIN',
#  'Approx.10 min',
#  '5 mins',
#  '60 min so far',
#  'sudden',
#  '8-10 min.',
#  '17:26',
#  'approx 7min',
#  '1-9 minutes',
#  'under a minute',
#  '6 to 10 minutes',
#  '3-5  seconds',
#  '4 Sec',
#  'MONTHS',
#  '2:00-4:00',
#  '5-7minutes',
#  '45 minutews',
#  "00:01'",
#  '7:40 PM',
#  '>8 months',
#  'aprx 30 mins',
#  '1m 15 seconds',
#  '10+ minutes',
#  'Backyard',
#  '60  seconds',
#  'approx. 4 min.',
#  'Summary',
#  '2 houra',
#  '3 minute (x2)',
#  '3 sec',
#  '5mis',
#  '1 hour about',
#  '1300',
#  '5 min.s',
#  '78 minutes',
#  'maybe a minute',
#  'approx 20 seconds',
#  '07:15',
#  '~25 minutes',
#  '0:03',
#  'Picture',
#  '(minutes)',
#  '10-20 Min',
#  '0:10 Seconds',
#  '4:45',
#  'Drove by it',
#  'extremely brief, less tha',
#  'every 10 to 15 minutes',
#  'STILL IN PROGRESS',
#  'About 2 hours',
#  '3 frames',
#  'About 5-10mins',
#  '1/320 second',
#  '5-6 seconds.',
#  '1 to 3 min.',
#  'Still occurring',
#  'Currently still going',
#  'Over 20 minutes',
#  '110 seconds',
#  '30+minutes',
#  '20 plus minutes',
#  'kept coming back every fe',
#  '5min+',
#  '30 minutess',
#  'Just over 1 minute',
#  'a number of hours',
#  '50 minutes',
#  '3 hhours',
#  ':20 min.',
#  '8+ minutes',
#  '30 nins',
#  'Light/orb',
#  '30 seconds',
#  'Maybe an hour',
#  '~1 minutes',
#  'over 3 hours',
#  '2-2 1/2 hours',
#  '2-3 MIN.',
#  'moving down slow',
#  '40',
#  'maybe three minutes',
#  '15-320 minutes',
#  '00:02 minutes',
#  'once',
#  '35 seoonds',
#  '7.30 min',
#  '5-10 minutes',
#  '5 to 7 minutes',
#  '23-24 minutes',
#  'Dark to Dawn',
#  '1:00:00',
#  '6 minites',
#  'seen in view only a coupl',
#  '~8-9 minutes',
#  '1 minute then came back a',
#  '1 second flashes',
#  '10 seconds',
#  '38- 40+ minutes',
#  '8 months',
#  '3-5 mins',
#  '1-2 sec',
#  'only a few seconds',
#  '~10',
#  'still going at 6:22',
#  '30 MINUTES',
#  'east',
#  '15 Mins.',
#  '15 minutes or more',
#  'night',
#  '45 minutes to an hour',
#  'about 5 mins',
#  'approx 10 sec',
#  '2 hrs at least',
#  '01:44-01:48',
#  '45-60seconds',
#  '5 secs',
#  'Less than 10 mins',
#  'second or two',
#  '1-2 Hours',
#  '1-2MINUTES',
#  'Route 6',
#  '115',
#  'Twenty minutes',
#  '173 seconds',
#  '21:00-22:00',
#  '1 hour (still happening)',
#  '7 mins',
#  '35 sec',
#  '20 minutes (approx.)',
#  '10-15seconds',
#  '> 30 minutes',
#  '~ 10-15 seconds',
#  'approx.  10 min',
#  'around 10 min',
#  '1min aprox.',
#  '~13 minutes',
#  '1Hr',
#  '2-10 minutes',
#  'most of the night',
#  '21:06',
#  '<1min',
#  'about 3 hours of lost tim',
#  'Night',
#  '~4 hours on two nights',
#  '6 houres',
#  '3 min at least',
#  '1- 2 min',
#  '20  seconds',
#  '1 hour or more',
#  'over one hour',
#  '90 - 120 seconds',
#  'appx 3 min',
#  '3.minutes',
#  'About 45 Minutes',
#  '25 +',
#  'under 4 min',
#  '5 to 10 mins',
#  '10+ Minutes',
#  'Currently happening',
#  '25-30 secs',
#  '0:15 sec',
#  '7-18 min',
#  '45 minutes',
#  '13 Seconds',
#  'Of and on for an hour',
#  '5 minutea',
#  '0:00:03',
#  'About 30 Seconds',
#  '30_40 minutes',
#  '10 - 20 secs',
#  '10:08',
#  '3 - 4 minutes',
#  '1O  MINUTES',
#  '3: mins',
#  'seconds per sighting',
#  'about 45 seconds',
#  '7 Min',
#  '5 minutes-intervals',
#  '60 seconds',
#  'on-going',
#  '2-5 mins.',
#  '1 minute 30 sec',
#  '30Seconds',
#  '15  mins',
#  '2 hrs',
#  '3 days+',
#  '45 secs.',
#  '30mins +',
#  'Less than 2 minutes',
#  '02:02',
#  '5 - 7 min',
#  '1 second',
#  'intermittent/10 mins',
#  'Unknown, but witnessed fo',
#  'City vanishing',
#  '>1 hour +',
#  'over and hour',
#  '1:30 sec',
#  '2.3 minutes',
#  '21:00-21:20',
#  '1 minute for each of 3 ev',
#  '2:30',
#  'less than 1 min.',
#  'About 30 min.',
#  '5 minutes observed',
#  '1-2 Mins',
#  '4-6 hours',
#  '~ 1 min',
#  'half and hour',
#  '5 minutes',
#  '8-10sec',
#  '20 sec or more',
#  '23 seconds',
#  '25 s',
#  '9:00',
#  'Several Seconds',
#  '3 to 5 secs',
#  '1-2 min.',
#  'segundos',
#  '1.5-2 seconds',
#  'UNKNOWEN',
#  '1 to 1 1/2 minutes',
#  '15m (estimated)',
#  'Roughly 1 hour',
#  'twenty minutes',
#  '10-17 seconds',
#  'Only saw in photo',
#  '10 seconds ea',
#  'UNKOWN',
#  'about 6 min',
#  '30 secs-1min',
#  '45-60 minutes',
#  '5 minutes+',
#  '20 secs.',
#  '~1 seconds',
#  '12 Hours',
#  'I only observed for 5-10 ',
#  '2 minutes, twice',
#  '2 MINUTES',
#  'getting ready for soccer',
#  '3 minuted',
#  '60+ minutes',
#  'a couple minutes',
#  '55 minutes',
#  'drive-by',
#  '3-4 Min.',
#  '15 + Minutes',
#  'A brief minute',
#  'about 1 minute',
#  '3',
#  'years',
#  '-',
#  '00:05:00.00',
#  '30 seconds or so',
#  '60s',
#  '20 seonds',
#  '1 Hour +',
#  '20s',
#  '2-3 minutes per occura',
#  '.5 second',
#  '2minutes',
#  '5 sec',
#  ...}

# %% [markdown]
# Created a couple functions to aid in cleaning/ standardizing the duration texts and converting them in terms of minutes

# %%
import pandas as pd
import numpy as np
import re
from quantulum3 import parser

# Sample data: replace with your actual data
duration

# Create a DataFrame (or use your existing DataFrame)
df = pd.DataFrame(list(duration), columns=['duration'])

# Function to convert words to numbers
def word_to_num(word):
    word_map = {
        "one": 1, "two": 2, "three": 3, "four": 4, "five": 5,
        "six": 6, "seven": 7, "eight": 8, "nine": 9, "ten": 10,
        "half": 0.5, "quarter": 0.25, "thirty": 30
    }
    return word_map.get(word.lower(), None)

# Function to clean and standardize the time durations
def standardize_duration(duration):
    if isinstance(duration, str):
        # Lowercase the input to avoid case issues
        duration = duration.lower()
        
        # Remove unwanted characters (e.g., '?', (', ')') keep "-", "/",":", "."
        duration = re.sub(r'[^a-zA-Z0-9\s./\-:]', '', duration)

        duration = re.sub(r'(?<=\d)\.(?=\D)', '', duration)  # Remove dot if it is not between digits
        duration = re.sub(r'(?<=\d)(?=\.\d)', '.', duration)  # Keep the dot if it is between digits
        
        # Convert any word-based numbers into numeric values
        words = duration.split()
        for i, word in enumerate(words):
            num_value = word_to_num(word)
            if num_value is not None:
                words[i] = str(num_value)  # Replace word with its numeric equivalent
        duration = ' '.join(words)
        
        # Handle time ranges like '5-10 minutes'
        if '-' in duration or 'to' in duration or '/' in duration:
            numbers = re.findall(r'\d+\.?\d*', duration)  # Find all numbers (including decimals)
            
            if len(numbers) == 2:  # If there are exactly two numbers (range)
                avg = np.mean([float(numbers[0]), float(numbers[1])])  # Calculate the average
                
                # Convert to minutes if the unit is 'minute' or 'min'
                if 'minute' in duration or 'min' in duration or 'minutes' in duration:
                    return f"{avg:.6f}"  # Return as string with six decimal places
                
                # Convert to minutes if the unit is 'hour' or 'hours'
                if 'hour' in duration or 'hours' in duration or 'hr' in duration or 'hrs' in duration:
                    return f"{avg * 60:.6f}"  # Convert hours to minutes and return as string
                
                # Convert to minutes if the unit is 'second' or 'sec'
                if 'second' in duration or 'sec' in duration or 'secs' in duration:
                    return f"{avg / 60:.6f}"  # Convert seconds to minutes and return as string
                
                return f"{avg:.6f}"  # Return the average value as a string with 6 decimals
        
        # Handle values with time units (minutes or hours)
        if 'minute' in duration or 'min' in duration or 'minutes' in duration:
            minutes = re.findall(r'\d+\.?\d*', duration)
            if minutes:
                return f"{minutes[0]}"
        
        if 'hour' in duration or 'hours' in duration or 'hr' in duration:
            hours = re.findall(r'\d+\.?\d*', duration)
            if hours:
                return f"{float(hours[0]) * 60}"  # Convert to minutes directly
            
        if 'second' in duration or 'sec' in duration or 'secs' in duration:
            second = re.findall(r'\d+\.?\d*', duration)
            if second:
                return f"{float(second[0]) / 60}"  # Convert to minutes
        
        # Handle specific cases (e.g., "one", "half")
        if 'one' in duration:
            return "1 minute"  # One minute
        elif 'half' in duration:
            return "30 minutes"  # Half an hour
        
        # Handle unknown or unparseable cases (return NaN)
        return np.nan

# Function to parse duration string into minutes
def parse_duration_to_minutes(text):
    if isinstance(text, str):
        quantities = parser.parse(text)
        for q in quantities:
            value = q.value
            unit = q.unit.name.lower()
            
            if 'second' in unit:
                return value / 60
            elif 'minute' in unit:
                return value
            elif 'hour' in unit:
                return value * 60
            elif 'day' in unit:
                return value * 1440  # 24 * 60
    return np.nan  # If no recognizable duration found

# Apply the function to clean and standardize durations, then parse to minutes
df['standardized_duration'] = df['duration'].apply(standardize_duration)

# Step 2: Identify rows where 'standardized_duration' is NaN
subset_df = df[df['standardized_duration'].isna()]

# Step 3: Apply the parse_duration_to_minutes function to the subset
subset_df['standardized_duration'] = subset_df['duration'].apply(parse_duration_to_minutes)

# Step 4: Update the original DataFrame with the new values from subset_df
df.update(subset_df)

# Show the result
print(df[['duration', 'standardized_duration']][301:350])
# Out:
#                       duration standardized_duration
# 301   45 seconds to One minute             23.000000
# 302                ~3 minutes.                     3
# 303                 50 Seconds    0.8333333333333334
# 304             2 mins or less                     2
# 305                  20+ secs.    0.3333333333333333
# 306              12:00 to 3:00                   NaN
# 307                      Brief                   NaN
# 308              65-70 seconds              1.125000
# 309               1/400 second              3.341667
# 310                      07:30                   NaN
# 311                       disk                   NaN
# 312                ~25 seconds    0.4166666666666667
# 313                   3 hours?                 180.0
# 314              20-22 seconds              0.350000
# 315                1.2 minutes                    1.
# 316     one and a half minutes                     1
# 317                 25 MINUTES                    25
# 318                <30 seconds                   0.5
# 319           Viewed 5 minutes                     5
# 320            1/8 of 1 second  0.016666666666666666
# 321        Less than 5 minutes                     5
# 322                      23:40                   NaN
# 323                  15 minits                    15
# 324                    40 secs    0.6666666666666666
# 325       fly by a few seconds                   NaN
# 326         5 Minutes (apporx)                     5
# 327                  2,minutes                     2
# 328            up to 5 minutes                     5
# 329            hour and a half                  30.0
# 330                walking dog                   NaN
# 331                 36 seconds                   0.6
# 332                   18 hours                1080.0
# 333                 one second  0.016666666666666666
# 334             about 1 second  0.016666666666666666
# 335                       1.14                   NaN
# 336                1-2 minutes              1.500000
# 337          8 minutes approx.                     8
# 338            7 days straight               10080.0
# 339                  dont know                   NaN
# 340           approx. 2-3 min?              2.500000
# 341             A half an hour                  30.0
# 342              1-1 1/2 hours                  60.0
# 343              Before School                   NaN
# 344              5 min or less                     5
# 345              One hour plus                  60.0
# 346                      -5min                     5
# 347                 >3 minutes                     3
# 348                  4.5 Hours                 240.0
# 349  30 minutes (and counting)                    30
# C:\Users\mayap\AppData\Local\Temp\ipykernel_17820\480546602.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['standardized_duration'] = subset_df['duration'].apply(parse_duration_to_minutes)

# %% [markdown]
# Adding cleaned_duration column to ufo_data dataframe

# %%
# Apply the function to clean and standardize durations, then parse to minutes
ufo_data['cleaned_duration'] = ufo_data['duration'].apply(standardize_duration)

# Step 2: Identify rows where 'standardized_duration' is NaN
subset_df = ufo_data[ufo_data['cleaned_duration'].isna()]

# Step 3: Apply the parse_duration_to_minutes function to the subset
subset_df['cleaned_duration'] = subset_df['cleaned_duration'].apply(parse_duration_to_minutes)

# Step 4: Update the original DataFrame with the new values from subset_df
ufo_data.update(subset_df)
ufo_data
# Out:
# C:\Users\mayap\AppData\Local\Temp\ipykernel_17820\1256567302.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['cleaned_duration'] = subset_df['cleaned_duration'].apply(parse_duration_to_minutes)
#                  city state           date_time      shape     duration  \
# 0             Chester    VA 2019-12-12 18:43:00      light    5 seconds
# 1          Rocky Hill    CT 2019-03-22 18:30:00     circle  3-5 seconds
# 2                 NaN   NaN                 NaT        NaN          NaN
# 3              Ottawa    ON 2019-04-17 02:00:00   teardrop   10 seconds
# 4              Peoria    NY 2009-03-15 18:00:00      cigar    2 minutes
# ...               ...   ...                 ...        ...          ...
# 88120           Tempe    AZ 2019-10-02 20:00:00  formation    3 minutes
# 88121         Bolivar    MO 2019-10-02 20:00:00      light   20 seconds
# 88122      North Port    FL 2019-10-02 20:03:00  formation   20 seconds
# 88123  Black Mountain    NC 2019-10-02 22:00:00   fireball    2 minutes
# 88124    Marin County    CA 2019-10-02 22:00:00     sphere    3 minutes
#
#                                                     text     posted  \
# 0      My wife was driving southeast on a fairly popu... 2019-12-22
# 1      I think that I may caught a UFO on the NBC Nig... 2019-03-29
# 2      I woke up late in the afternoon 3:30-4pm.  I w...        NaT
# 3      I was driving towards the intersection of fall... 2019-04-18
# 4      In Peoria, Arizona, I saw a cigar shaped craft... 2019-04-18
# ...                                                  ...        ...
# 88120  4 lights in formation over Tempe appear while ... 2019-10-04
# 88121  2 bright star like lights in the NNW sky two b... 2019-10-04
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428... 2019-10-04
# 88123  Witnessed an orange, slow moving light. Was lo... 2019-10-04
# 88124  Glowing lights in formation  just south of San... 2019-10-04
#
#        city_latitude  city_longitude  time_diff_minutes  word_count  \
# 0          37.343152      -77.408582            13277.0         185
# 1          41.664800      -72.639300             8970.0          73
# 2                NaN             NaN                NaN         178
# 3          45.381383      -75.708501             1320.0          49
# 4                NaN             NaN          5306760.0         211
# ...              ...             ...                ...         ...
# 88120      33.414036     -111.920920             1680.0         118
# 88121      37.642200      -93.399600             1680.0          78
# 88122      27.076210      -82.223280             1677.0         113
# 88123      35.605000      -82.313200             1560.0          72
# 88124            NaN             NaN             1560.0         107
#
#           cleaned_duration
# 0      0.08333333333333333
# 1                 0.066667
# 2                     None
# 3      0.16666666666666666
# 4                        2
# ...                    ...
# 88120                    3
# 88121   0.3333333333333333
# 88122   0.3333333333333333
# 88123                    2
# 88124                    3
#
# [88125 rows x 12 columns]

# %%
ufo_data[ufo_data['cleaned_duration'].isna()]
# Out:
#                               city state           date_time     shape  \
# 2                              NaN   NaN                 NaT       NaN
# 9      Caloocan City (Philippines)   NaN 2019-06-06 19:00:00     other
# 11                 Melbourne Beach    FL 2019-06-12 22:00:00   unknown
# 12                       Carrizozo    NM 2019-06-11 22:00:00  changing
# 25                     Clarksville    TN 2019-07-25 19:06:00       NaN
# ...                            ...   ...                 ...       ...
# 88093                     Newburgh    IN 2019-10-01 00:00:00   diamond
# 88094                     Newburgh    IN 2019-10-01 00:00:00   diamond
# 88098             Port Saint Lucie    FL 2019-10-01 04:45:00     light
# 88101                     Brampton    ON 2019-10-01 18:30:00  changing
# 88108                   Twin Falls    ID 2019-10-01 21:30:00    circle
#
#              duration                                               text  \
# 2                 NaN  I woke up late in the afternoon 3:30-4pm.  I w...
# 9      19:00 to 19:30  group of lights formation sweeping thru a nigh...
# 11               Hour  We think 2 UFOs....2 tiny lights recorded for ...
# 12        Few minutes  I was driving and saw three glowing orbs is th...
# 25                NaN                                     MADAR Node 138
# ...               ...                                                ...
# 88093             NaN  ((NUFORC Note:  Witness does not include any d...
# 88094             NaN  ((NUFORC Note:  Witness does not include any d...
# 88098         Seconds  Awoke unknown reason. Heard noise of unknown o...
# 88101     Few minutes  dark object moving very straight, high and fas...
# 88108             NaN  Circle like object with white and red lights h...
#
#           posted  city_latitude  city_longitude  time_diff_minutes  \
# 2            NaT            NaN             NaN                NaN
# 9     2019-06-07            NaN             NaN              300.0
# 11    2019-06-20      27.966800      -80.509600            10200.0
# 12    2019-06-20      33.784900     -105.833200            11640.0
# 25    2019-08-23      36.515158      -87.361034            40614.0
# ...          ...            ...             ...                ...
# 88093 2019-10-04      37.956568      -87.352515             4320.0
# 88094 2019-10-04      37.956568      -87.352515             4320.0
# 88098 2019-10-04      27.285686      -80.363444             4035.0
# 88101 2019-10-04      43.710661      -79.758429             3210.0
# 88108 2019-10-04      42.433109     -114.579445             3030.0
#
#        word_count cleaned_duration
# 2             178             None
# 9             114              NaN
# 11             39              NaN
# 12             81              NaN
# 25              3             None
# ...           ...              ...
# 88093          13             None
# 88094          13             None
# 88098          31              NaN
# 88101         153              NaN
# 88108          80             None
#
# [10973 rows x 12 columns]

# %% [markdown]
# 10,973 entries have Nan as a cleaned_duration (~12.5% of the full dataset)
